# %% [markdown]
# # 1st Data visualisation and web scraping
#
#   * In this task you should download (*scrape*) data from the web, process it and visualise.
#   * The objective is to download data from server https://www.psp.cz/en/sqw/hlasovani.sqw?o=8 regarding voting in the Chamber of Deputies of the Parliament of the Czech Republic, save it in a tabular form and create visualisations, which make exploration of the data easier and show interesting information about it.
#
# ## Data
#
#  * Download data from all votings of the current Chamber of Deputies (since 2017). Download details of voting of particular deputies.
#  * Data should contain basic information about the voting - number of meeting, number of voting, point of the meeting and date.
#
# ## Instructions
#
#
# **Basic points of the assignment**:
#   * Write Python script for downloading data. Download the data and save it in a suitable machine-readable format.
#   * **Wait at least 1 second between two consecutive requests to the server, to not overload it.**
#   * In the second part of the notebook, work with the data loaded from a local file. File(s) with downloaded data should be submitted as well (so the reviewer do not have to download the data again).
#   * Create visualisations to show the following:
#     * Deputies changing their parliamentary clubs.
#     * Attendance of individual deputies in the votings. Attendance of parliamentary clubs in the votings.
#     * How often individual parliamentary clubs vote the same and different.
#     * Are deputies in the same parliamentary club voting the same? Who are the biggest rebels?
#
#   * Visualise some time development in the data (e.g. attendance, change of agreement in voting among individual parliamentary clubs, etc.)
#   * Find individual deputies who have the most similar voting or attendance.
#   * Try to find particular voting, where deputies voted the most differently than traditionally.
#
# ## Tips and tricks
#   * Import libraries at the beginning of the notebook, or the beginning of scraping and visualisation parts.
#   * Use markdown cells (like this one) and headings to make orientation in the notebook easier.
#   * Select plots and visualisation matching the information you want to show. You can see galleries of libraries `matplotlib` and `seaborn` for inspiration.

# %%
import requests
from requests import get
from bs4 import BeautifulSoup 
import pandas as pd
import numpy as np
from time import sleep
import datetime
from collections import Counter
from random import randint
import seaborn as sb
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
from seaborn import countplot
import csv
import re
import os
import glob

# %% [markdown]
# #### Getting urls of  62 meetings:

# %%
URLs = []

template_url = 'https://www.psp.cz/en/sqw/phlasa.sqw?o=8&s={}&pg=1'
range_first_pages = range(1,63)
for first_page in range_first_pages:
    #if first_page in urls_with_subpages:
    if first_page != 10 and first_page != 21:
        URLs.append(template_url.format(first_page,range_first_pages))            
    else:
        continue

# %%
#for i in  URLs:
    #print('URLs:', i)

# %% [markdown]
# #### Getting urls of  subpages of each meeting:

# %%
global unique_URLs_next_pages
unique_URLs_next_pages = []

def get_links(root_url):    
    URLs_next_pages = set()    
    while True:        
        r = requests.get(root_url)
        first_link = BeautifulSoup(r.text, 'html.parser')
        base_url = 'https://www.psp.cz/en/sqw/'
        for p_tag in first_link.find_all('p', class_='paging'):
            for a_tag in p_tag.find_all('a', class_=None):
                check_url = a_tag['href']
                if check_url.startswith('phlasa.sqw?o=8'):
                    valid_url = base_url + a_tag['href']
                    URLs_next_pages.add(valid_url)
        next_page = first_link.find('a', class_='next')    
        if next_page:
            next_url = a_tag['href']
            if next_url:
                root_url = base_url + a_tag['href']
            else:
                break
        else:
            URLs_next_pages.add(root_url)
            break
    for element in URLs_next_pages:
        unique_URLs_next_pages.append(element)
        
    return unique_URLs_next_pages

# %%
for i in URLs:
    unique_URLs_next_pages = get_links(i)

# %% [markdown]
# #### Opening each url of subpages, from which data will be scraped:

# %%
global ready_for_scraping
ready_for_scraping = []

def openning_pages_for_scraping(some_urls): 
    
    for url in some_urls:        
        url_links = requests.get(url)
        first_link = BeautifulSoup(url_links.text, 'html.parser') 
        
        url_all_links =[]
        base_url1 = 'https://www.psp.cz/en/sqw/'
        for td in first_link.find_all('td'):
            for a_tag in td.find_all('a', href=True):
                check_url1 = a_tag['href']
                #print("Found the URL:", check_url) 
                if check_url1.startswith('hlasy.sqw?g='):
                    valid_url = base_url1 + a_tag['href']
                    #print(valid_url)
                    ready_for_scraping.append(valid_url)
                else:
                    continue
    return ready_for_scraping

# %%
ready_for_scraping  = openning_pages_for_scraping(unique_URLs_next_pages)
len(ready_for_scraping)
# Out:
# 7323

# %% [markdown]
# #### The main code for scraping all needed  data from each subpages, the result is saved in dataframe in files HW1_1.csv', 'HW1_2.csv', 'HW1_3.csv', 'HW1_4.csv.

# %%
def scraping_data(urls):
   
    meeting_number =[]
    vote_number =[]
    vote_date =[]
    vote_time = []
    agenda =[]   
    vote = []
    clubs =[]
    deputies = []

    for url in urls:
        try:           
            vote_response = requests.get(url)
            sleep(randint(1,4))
            vote_page = BeautifulSoup(vote_response.text, 'html.parser') 

            meeting_number_tag = vote_page.find('h1', class_='page-title-x').next
            number_meeting = meeting_number_tag[:2].replace('.', '')                         
            print(number_meeting)

            number_vote_tag = meeting_number_tag.next
            number_vote = number_vote_tag.text[:3].replace('.', '')                                      
            print(number_vote)

            date_text = number_vote_tag.next.next
            date = date_text.replace(',','')[:-6]
            print(date)
            vote_timee = date_text.replace(',','')[-6:]
            
                
            agenda_meeting_tag = vote_page.h1.find('br')                 
            agenda_meeting = vote_page.h1.find('br').next_sibling
            print(agenda_meeting)

            
            for deputies_vote1 in vote_page.find('ul', class_='results'):
                deputies_vote1_text = deputies_vote1.text.replace('\xa0', '')
                club_vote1 = vote_page.h2.find_next('h2')            
                club1 = club_vote1.text
                name_club1 = re.sub('\(.*?\)', '',club1)
                clubs.append(name_club1) 


                meeting_number.append(number_meeting)
                vote_number.append(number_vote)
                vote_date.append(date)
                vote_time.append(vote_timee)                                  
                agenda.append(agenda_meeting)
                             
                for deputy in deputies_vote1_text[0]:
                    if deputy in 'N':
                        deputies.append(deputies_vote1_text[1:])
                        vote.append('ne')                                        
                    elif deputy in 'A':
                        deputies.append(deputies_vote1_text[1:])
                        vote.append('ano')                
                    elif deputy in '0':  
                        deputies.append(deputies_vote1_text[1:])
                        vote.append('neprihlasen')         
                    elif deputy in 'M':
                        deputies.append(deputies_vote1_text[1:])
                        vote.append('omluven')
                    elif deputy in 'Z':
                        deputies.append(deputies_vote1_text[1:])
                        vote.append('zdrzel')
            
            for deputies_vote2 in deputies_vote1.find_next('ul', class_='results'):
                deputies_vote2_text = deputies_vote2.text.replace('\xa0', '')
                club_vote2 = club_vote1.find_next('h2', class_='section-title center')
                club2 = club_vote2.text               
                name_club2 = re.sub('\(.*?\)', '',club2)
                clubs.append(name_club2) 
               
                meeting_number.append(number_meeting)
                vote_number.append(number_vote)
                vote_date.append(date)
                vote_time.append(vote_timee)                                  
                agenda.append(agenda_meeting)
                             
                for deputy in deputies_vote2_text[0]:
                    if deputy in 'N':
                        deputies.append(deputies_vote2_text[1:])
                        vote.append('ne')                                        
                    elif deputy in 'A':
                        deputies.append(deputies_vote2_text[1:])
                        vote.append('ano')                
                    elif deputy in '0':  
                        deputies.append(deputies_vote2_text[1:])
                        vote.append('neprihlasen')         
                    elif deputy in 'M':
                        deputies.append(deputies_vote2_text[1:])
                        vote.append('omluven')
                    elif deputy in 'Z':
                        deputies.append(deputies_vote2_text[1:])
                        vote.append('zdrzel')
                        
            for deputies_vote3 in deputies_vote2.find_next('ul', class_='results'):
                deputies_vote3_text = deputies_vote3.text.replace('\xa0', '')
                club_vote3 = club_vote2.find_next('h2', class_='section-title center')
                club3 = club_vote3.text              
                name_club3 = re.sub('\(.*?\)', '',club3)
                clubs.append(name_club3) 
             

                
                meeting_number.append(number_meeting)
                vote_number.append(number_vote)
                vote_date.append(date)
                vote_time.append(vote_timee)                                  
                agenda.append(agenda_meeting)
                             
                for deputy in deputies_vote3_text[0]:
                    if deputy in 'N':
                        deputies.append(deputies_vote3_text[1:])
                        vote.append('ne')                                        
                    elif deputy in 'A':
                        deputies.append(deputies_vote3_text[1:])
                        vote.append('ano')                
                    elif deputy in '0':  
                        deputies.append(deputies_vote3_text[1:])
                        vote.append('neprihlasen')         
                    elif deputy in 'M':
                        deputies.append(deputies_vote3_text[1:])
                        vote.append('omluven')
                    elif deputy in 'Z':
                        deputies.append(deputies_vote3_text[1:])
                        vote.append('zdrzel')
                        
            for deputies_vote4 in deputies_vote3.find_next('ul', class_='results'):
                deputies_vote4_text = deputies_vote4.text.replace('\xa0', '')
                club_vote4 = club_vote3.find_next('h2', class_='section-title center')
                club4 = club_vote4.text               
                name_club4 = re.sub('\(.*?\)', '',club4)
                clubs.append(name_club4) 
 
                meeting_number.append(number_meeting)
                vote_number.append(number_vote)
                vote_date.append(date)
                vote_time.append(vote_timee)                                  
                agenda.append(agenda_meeting)
                             
                for deputy in deputies_vote4_text[0]:
                    if deputy in 'N':
                        deputies.append(deputies_vote4_text[1:])
                        vote.append('ne')                                        
                    elif deputy in 'A':
                        deputies.append(deputies_vote4_text[1:])
                        vote.append('ano')                
                    elif deputy in '0':  
                        deputies.append(deputies_vote4_text[1:])
                        vote.append('neprihlasen')         
                    elif deputy in 'M':
                        deputies.append(deputies_vote4_text[1:])
                        vote.append('omluven')
                    elif deputy in 'Z':
                        deputies.append(deputies_vote4_text[1:])
                        vote.append('zdrzel')

            for deputies_vote5 in deputies_vote4.find_next('ul', class_='results'):
                deputies_vote5_text = deputies_vote5.text.replace('\xa0', '')
                club_vote5 = club_vote4.find_next('h2', class_='section-title center')
                club5 = club_vote5.text             
                name_club5 = re.sub('\(.*?\)', '',club5)
                clubs.append(name_club5) 
 
                meeting_number.append(number_meeting)
                vote_number.append(number_vote)
                vote_date.append(date)
                vote_time.append(vote_timee)                                  
                agenda.append(agenda_meeting)
                             
                for deputy in deputies_vote5_text[0]:
                    if deputy in 'N':
                        deputies.append(deputies_vote5_text[1:])
                        vote.append('ne')                                        
                    elif deputy in 'A':
                        deputies.append(deputies_vote5_text[1:])
                        vote.append('ano')                
                    elif deputy in '0':  
                        deputies.append(deputies_vote5_text[1:])
                        vote.append('neprihlasen')         
                    elif deputy in 'M':
                        deputies.append(deputies_vote5_text[1:])
                        vote.append('omluven')
                    elif deputy in 'Z':
                        deputies.append(deputies_vote5_text[1:])
                        vote.append('zdrzel')
             
            for deputies_vote6 in deputies_vote5.find_next('ul', class_='results'):
                deputies_vote6_text = deputies_vote6.text.replace('\xa0', '')
                club_vote6 = club_vote5.find_next('h2', class_='section-title center')
                club6 = club_vote6.text               
                name_club6 = re.sub('\(.*?\)', '',club6)
                clubs.append(name_club6) 

                meeting_number.append(number_meeting)
                vote_number.append(number_vote)
                vote_date.append(date)
                vote_time.append(vote_timee)                                  
                agenda.append(agenda_meeting)
                             
                for deputy in deputies_vote6_text[0]:
                    if deputy in 'N':
                        deputies.append(deputies_vote6_text[1:])
                        vote.append('ne')                                        
                    elif deputy in 'A':
                        deputies.append(deputies_vote6_text[1:])
                        vote.append('ano')                
                    elif deputy in '0':  
                        deputies.append(deputies_vote6_text[1:])
                        vote.append('neprihlasen')         
                    elif deputy in 'M':
                        deputies.append(deputies_vote6_text[1:])
                        vote.append('omluven')
                    elif deputy in 'Z':
                        deputies.append(deputies_vote6_text[1:])
                        vote.append('zdrzel')
                        
            for deputies_vote7 in deputies_vote6.find_next('ul', class_='results'):
                deputies_vote7_text = deputies_vote7.text.replace('\xa0', '')
                club_vote7 = club_vote6.find_next('h2', class_='section-title center')
                club7 = club_vote7.text               
                name_club7 = re.sub('\(.*?\)', '',club7)
                clubs.append(name_club7) 

                meeting_number.append(number_meeting)
                vote_number.append(number_vote)
                vote_date.append(date)
                vote_time.append(vote_timee)                                  
                agenda.append(agenda_meeting)
                             
                for deputy in deputies_vote7_text[0]:
                    if deputy in 'N':
                        deputies.append(deputies_vote7_text[1:])
                        vote.append('ne')                                        
                    elif deputy in 'A':
                        deputies.append(deputies_vote7_text[1:])
                        vote.append('ano')                
                    elif deputy in '0':  
                        deputies.append(deputies_vote7_text[1:])
                        vote.append('neprihlasen')         
                    elif deputy in 'M':
                        deputies.append(deputies_vote7_text[1:])
                        vote.append('omluven')
                    elif deputy in 'Z':
                        deputies.append(deputies_vote7_text[1:])
                        vote.append('zdrzel')
                        
            for deputies_vote8 in deputies_vote7.find_next('ul', class_='results'):
                deputies_vote8_text = deputies_vote8.text.replace('\xa0', '')
                club_vote8 = club_vote7.find_next('h2', class_='section-title center')
                club8 = club_vote8.text               
                name_club8 = re.sub('\(.*?\)', '',club8)
                clubs.append(name_club8) 

                meeting_number.append(number_meeting)
                vote_number.append(number_vote)
                vote_date.append(date)
                vote_time.append(vote_timee)                                  
                agenda.append(agenda_meeting)
                             
                for deputy in deputies_vote8_text[0]:
                    if deputy in 'N':
                        deputies.append(deputies_vote8_text[1:])
                        vote.append('ne')                                        
                    elif deputy in 'A':
                        deputies.append(deputies_vote8_text[1:])
                        vote.append('ano')                
                    elif deputy in '0':  
                        deputies.append(deputies_vote8_text[1:])
                        vote.append('neprihlasen')         
                    elif deputy in 'M':
                        deputies.append(deputies_vote8_text[1:])
                        vote.append('omluven')
                    elif deputy in 'Z':
                        deputies.append(deputies_vote8_text[1:])
                        vote.append('zdrzel')
                        
            for deputies_vote9 in deputies_vote8.find_next('ul', class_='results'):
                deputies_vote9_text = deputies_vote9.text.replace('\xa0', '')
                club_vote9 = club_vote8.find_next('h2', class_='section-title center')
                club9 = club_vote9.text               
                name_club9 = re.sub('\(.*?\)', '',club9)
                clubs.append(name_club9) 

                meeting_number.append(number_meeting)
                vote_number.append(number_vote)
                vote_date.append(date)
                vote_time.append(vote_timee)                                  
                agenda.append(agenda_meeting)
                             
                for deputy in deputies_vote9_text[0]:
                    if deputy in 'N':
                        deputies.append(deputies_vote9_text[1:])
                        vote.append('ne')                                        
                    elif deputy in 'A':
                        deputies.append(deputies_vote9_text[1:])
                        vote.append('ano')                
                    elif deputy in '0':  
                        deputies.append(deputies_vote9_text[1:])
                        vote.append('neprihlasen')         
                    elif deputy in 'M':
                        deputies.append(deputies_vote9_text[1:])
                        vote.append('omluven')
                    elif deputy in 'Z':
                        deputies.append(deputies_vote9_text[1:])
                        vote.append('zdrzel')
            try:            
                for deputies_vote10 in deputies_vote9.find_next('ul', class_='results'):
                    deputies_vote10_text = deputies_vote10.text.replace('\xa0', '')
                    club_vote10 = club_vote9.find_next('h2', class_='section-title center')
                    club10 = club_vote10.text               
                    name_club10 = re.sub('\(.*?\)', '',club10)
                    clubs.append(name_club10) 

                    meeting_number.append(number_meeting)
                    vote_number.append(number_vote)
                    vote_date.append(date)
                    vote_time.append(vote_timee)                                  
                    agenda.append(agenda_meeting)

                    for deputy in deputies_vote10_text[0]:
                        if deputy in 'N':
                            deputies.append(deputies_vote10_text[1:])
                            vote.append('ne')                                        
                        elif deputy in 'A':
                            deputies.append(deputies_vote10_text[1:])
                            vote.append('ano')                
                        elif deputy in '0':  
                            deputies.append(deputies_vote10_text[1:])
                            vote.append('neprihlasen')         
                        elif deputy in 'M':
                            deputies.append(deputies_vote10_text[1:])
                            vote.append('omluven')
                        elif deputy in 'Z':
                            deputies.append(deputies_vote10_text[1:])
                            vote.append('zdrzel')
                            
            except:
                pass            
        
               
            Data = pd.DataFrame({ 
                'meeting_no': pd.Series(meeting_number, dtype=pd.StringDtype()),
                'vote_no': pd.Series(vote_number,dtype=pd.StringDtype()),
                'vote_date': pd.Series(vote_date,dtype=pd.StringDtype()),
                'vote_time': pd.Series(vote_time,dtype=pd.StringDtype()),
                'agenda': pd.Series(agenda,dtype=pd.StringDtype()),
                'clubs':pd.Series(clubs,dtype=pd.StringDtype()),
                'deputies': pd.Series(deputies,dtype=pd.StringDtype()),
                'vote': pd.Series(vote,dtype=pd.StringDtype()),    
                })

            Data['meeting_no'],
            Data['vote_no'],
            Data['vote_date'],
            Data['vote_time']
            Data['agenda'],
            Data['clubs']
            Data['deputies'],    
            Data['vote']

            print('Ok')
            Data.to_csv('HW1_4.csv', index=False)
        except:
            print('Cannot open page')
            continue

# %%
scraping_data(ready_for_scraping)
# Out:
# 1
#
# Cannot open page
# 1
# 2
#  20. listopadu 2017
# Inf. o ustavení volební komise PS a volbě členů
# Ok
# 1
# 3
#  20. listopadu 2017
# None
# Ok
# 1
# 4
#  20. listopadu 2017
# Náv.na stanovení počtu čl. MIV
# Ok
# 1
# 5
#  20. listopadu 2017
# Náv.na stanovení počtu čl. MIV
# Ok
# 1
# 6
#  22. listopadu 2017
# Návrh na ustavení MIV
# Ok
# 1
# 7
#  22. listopadu 2017
# Návrh na potvrzení předsedy MIV
# Ok
# 1
# 8
#  22. listopadu 2017
# Inf. MIV o ověření platnosti volby poslanců
# Ok
# 1
# 9
#  22. listopadu 2017
# Návrh na stanovení počtu místopředsedů PS
# Ok
# 1
# 10
#  22. listopadu 2017
# Návrh na stanovení počtu místopředsedů PS
# Ok
# 1
# 11
#  24. listopadu 2017
# Návrh na stanovení počtu ověřovatelů PS
# Ok
# 1
# 12
#  24. listopadu 2017
# Návrh na nominaci ověřovatelů PS
# Ok
# 1
# 13
#  24. listopadu 2017
# Návrh na nominaci ověřovatelů PS
# Ok
# 1
# 14
#  24. listopadu 2017
# Návrh na zřízení výborů PS
# Ok
# 1
# 15
#  24. listopadu 2017
# Návrh na stanovení počtu členů výborů PS
# Ok
# 1
# 16
#  24. listopadu 2017
# Návrh termínu 2. schůze PS
# Ok
# 2
# 1
#  28. listopadu 2017
# None
# Ok
# 2
# 2
#  28. listopadu 2017
# Pořad schůze
# Ok
# 2
# 3
#  28. listopadu 2017
# Pořad schůze
# Ok
# 2
# 4
#  28. listopadu 2017
# Náv. na ustavení výborů PS
# Ok
# 2
# 5
#  28. listopadu 2017
# Náv. na ustavení výborů PS
# Ok
# 2
# 6
#  28. listopadu 2017
# Náv. na ustavení výborů PS
# Ok
# 2
# 7
#  28. listopadu 2017
# Náv. na ustavení výborů PS
# Ok
# 2
# 8
#  28. listopadu 2017
# Náv. na ustavení výborů PS
# Ok
# 2
# 9
#  28. listopadu 2017
# Náv. na ustavení výborů PS
# Ok
# 2
# 10
#  28. listopadu 2017
# Náv. na ustavení výborů PS
# Ok
# 2
# 11
#  28. listopadu 2017
# Náv. na ustavení výborů PS
# Ok
# 2
# 12
#  28. listopadu 2017
# Náv. na ustavení výborů PS
# Ok
# 2
# 13
#  28. listopadu 2017
# Náv. na ustavení výborů PS
# Ok
# 2
# 14
#  28. listopadu 2017
# Náv. na ustavení výborů PS
# Ok
# 2
# 15
#  28. listopadu 2017
# Náv. na ustavení výborů PS
# Ok
# 2
# 16
#  28. listopadu 2017
# Náv. na ustavení výborů PS
# Ok
# 2
# 17
#  28. listopadu 2017
# Náv. na ustavení výborů PS
# Ok
# 2
# 18
#  28. listopadu 2017
# Náv. na ustavení výborů PS
# Ok
# 2
# 19
#  28. listopadu 2017
# Náv. na ustavení výborů PS
# Ok
# 2
# 20
#  28. listopadu 2017
# Náv. na ustavení výborů PS
# Ok
# 2
# 41
#  28. listopadu 2017
# Návrh na zřízení stálé komise pro kontrolu NBÚ
# Ok
# 2
# 42
#  28. listopadu 2017
# Návrh na zřízení stálé komise pro kontrolu NBÚ
# Ok
# 2
# 43
#  28. listopadu 2017
# Návrh na zřízení Stálé komise pro kontrolu VZ
# Ok
# 2
# 44
#  28. listopadu 2017
# Návrh na zřízení Stálé komise pro kontrolu VZ
# Ok
# 2
# 45
#  28. listopadu 2017
# Návrh na zřízení SK FAÚ
# Ok
# 2
# 46
#  28. listopadu 2017
# Návrh na zřízení SK FAÚ
# Ok
# 2
# 47
#  28. listopadu 2017
# Návrh na zřízení SK NÚKIB
# Ok
# 2
# 48
#  28. listopadu 2017
# Návrh na zřízení SK NÚKIB
# Ok
# 2
# 49
#  28. listopadu 2017
# Návrh na stanovení počtu poslanců ve stálých delegacích
# Ok
# 2
# 50
#  28. listopadu 2017
# Návrh na úhradu volebních nákladů za volby do PS v roce 2013
# Ok
# 2
# 51
#  30. listopadu 2017
# Pořad schůze
# Ok
# 2
#
# Cannot open page
# 2
# 53
#  30. listopadu 2017
# Náv. na potvrzení předsedů výborů PS
# Ok
# 2
# 54
#  30. listopadu 2017
# Náv. na potvrzení předsedů výborů PS
# Ok
# 2
# 55
#  30. listopadu 2017
# Náv. na potvrzení předsedů výborů PS
# Ok
# 2
# 56
#  30. listopadu 2017
# Náv. na potvrzení předsedů výborů PS
# Ok
# 2
# 57
#  30. listopadu 2017
# Náv. na potvrzení předsedů výborů PS
# Ok
# 2
# 58
#  30. listopadu 2017
# Náv. na potvrzení předsedů výborů PS
# Ok
# 2
# 59
#  30. listopadu 2017
# Náv. na potvrzení předsedů výborů PS
# Ok
# 2
# 60
#  30. listopadu 2017
# Náv. na potvrzení předsedů výborů PS
# Ok
# 2
# 21
#  28. listopadu 2017
# Návrh na potvrzení platnosti usnesení, kterými Poslanecká sněmovna upr
# Ok
# 2
# 22
#  28. listopadu 2017
# Náv. zasedacího pořádku poslanců v jedn. sále PS
# Ok
# 2
# 23
#  28. listopadu 2017
# Náv. zasedacího pořádku poslanců v jedn. sále PS
# Ok
# 2
# 24
#  28. listopadu 2017
# Náv. zasedacího pořádku poslanců v jedn. sále PS
# Ok
# 2
# 25
#  28. listopadu 2017
# Náv. zasedacího pořádku poslanců v jedn. sále PS
# Ok
# 2
# 26
#  28. listopadu 2017
# Návrh na zřízení stálých komisí PS
# Ok
# 2
# 27
#  28. listopadu 2017
# Návrh na zřízení SK GIBS a způsobu jejího ustavení nebo volby
# Ok
# 2
# 28
#  28. listopadu 2017
# Návrh na zřízení SK GIBS a způsobu jejího ustavení nebo volby
# Ok
# 2
# 29
#  28. listopadu 2017
# Návrh na zřízení SK GIBS a způsobu jejího ustavení nebo volby
# Ok
# 2
# 30
#  28. listopadu 2017
# Návrh na zřízení SK GIBS a způsobu jejího ustavení nebo volby
# Ok
# 2
# 31
#  28. listopadu 2017
# Návrh na zřízení SK KPO
# Ok
# 2
# 32
#  28. listopadu 2017
# Návrh na zřízení SK KPO
# Ok
# 2
# 33
#  28. listopadu 2017
# Návrh na zřízení SK KPO
# Ok
# 2
# 34
#  28. listopadu 2017
# Návrh na zřízení SK KPO
# Ok
# 2
# 35
#  28. listopadu 2017
# Návrh na ustavení SK CEÚ
# Ok
# 2
# 36
#  28. listopadu 2017
# Návrh na ustavení SK CEÚ
# Ok
# 2
# 37
#  28. listopadu 2017
# Návrh na ustavení SK CEÚ
# Ok
# 2
# 38
#  28. listopadu 2017
# Návrh na ustavení SK CEÚ
# Ok
# 2
# 39
#  28. listopadu 2017
# Návrh na zřízení Stálé komise pro kontrolu BIS
# Ok
# 2
# 40
#  28. listopadu 2017
# Návrh na zřízení Stálé komise pro kontrolu BIS
# Ok
# 2
# 61
#  30. listopadu 2017
# Náv. na potvrzení předsedů výborů PS
# Ok
# 2
# 62
#  30. listopadu 2017
# Náv. na potvrzení předsedů výborů PS
# Ok
# 2
# 63
#  30. listopadu 2017
# Náv. na potvrzení předsedů výborů PS
# Ok
# 2
# 64
#  30. listopadu 2017
# Náv. na potvrzení předsedů výborů PS
# Ok
# 2
# 65
#  30. listopadu 2017
# Náv. na potvrzení předsedů výborů PS
# Ok
# 2
# 66
#  30. listopadu 2017
# Náv. na potvrzení předsedů výborů PS
# Ok
# 2
# 67
#  30. listopadu 2017
# Náv. na potvrzení předsedů výborů PS
# Ok
# 2
# 68
#  30. listopadu 2017
# Náv. na potvrzení předsedů výborů PS
# Ok
# 2
# 69
#  30. listopadu 2017
# Náv. na potvrzení předsedů výborů PS
# Ok
# 2
# 70
#  30. listopadu 2017
# Náv. na potvrzení předsedů výborů PS
# Ok
# 2
# 71
#  30. listopadu 2017
# Návrh časového harmonogramu projednávání SR 2018
# Ok
# 2
# 72
#  30. listopadu 2017
# Žádost o vyslovení souhlasu s tr. stíháním poslanců
# Ok
# 2
# 73
#  30. listopadu 2017
# Žádost o vyslovení souhlasu PS k trestnímu stíhání poslance
# Ok
# 2
# 74
#  30. listopadu 2017
# Návrh na změny ve složení orgánů Poslanecké sněmovny
# Ok
# 3
# 1
#  5. prosince 2017
# None
# Ok
# 3
# 2
#  5. prosince 2017
# None
# Ok
# 3
#
# Cannot open page
# 3
# 4
#  5. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 3
# 5
#  5. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 3
# 6
#  5. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 3
# 7
#  5. prosince 2017
# Novela z. o léčivech - EU
# Ok
# 3
# 8
#  5. prosince 2017
# Novela z. o léčivech - EU
# Ok
# 3
# 9
#  5. prosince 2017
# Novela z. o léčivech - EU
# Ok
# 3
# 10
#  5. prosince 2017
# Novela z. o léčivech - EU
# Ok
# 3
# 11
#  5. prosince 2017
# Novela z. o léčivech - EU
# Ok
# 3
# 12
#  5. prosince 2017
# None
# Ok
# 4
# 121
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 122
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 123
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 124
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 125
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 126
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 127
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 128
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 129
#  19. prosince 2017
# Střednědobý výhled státního rozpočtu ČR na léta 2019 a 2020
# Ok
# 4
# 130
#  19. prosince 2017
# Rozpočet SFDI na rok 2018
# Ok
# 4
# 131
#  19. prosince 2017
# Rozpočet SFDI na rok 2018
# Ok
# 4
# 132
#  19. prosince 2017
# Návrh rozpočtu SFRB na rok 2018
# Ok
# 4
# 133
#  19. prosince 2017
# Návrh rozpočtu SZIF na rok 2018
# Ok
# 4
# 134
#  19. prosince 2017
# Dotační programy zemědělství pro rok 2018
# Ok
# 4
# 135
#  19. prosince 2017
# None
# Ok
# 4
# 136
#  19. prosince 2017
# None
# Ok
# 4
# 81
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 82
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 83
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 84
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 85
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 86
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 87
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 88
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 89
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 90
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 91
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 92
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 93
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 94
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 95
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 96
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 97
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 98
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 99
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 100
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 61
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 62
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 63
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 64
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 65
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 66
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 67
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 68
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 69
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 70
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 71
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 72
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 73
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 74
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 75
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 76
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 77
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 78
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 79
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 80
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 1
#  12. prosince 2017
# None
# Ok
# 4
# 2
#  12. prosince 2017
# Pořad schůze
# Ok
# 4
# 3
#  12. prosince 2017
# Pořad schůze
# Ok
# 4
# 4
#  12. prosince 2017
# Pořad schůze
# Ok
# 4
# 5
#  12. prosince 2017
# Návrh na ustavení nebo volbu členů stálých komisí PS
# Ok
# 4
# 6
#  12. prosince 2017
# Návrh na ustavení nebo volbu členů stálých komisí PS
# Ok
# 4
# 7
#  12. prosince 2017
# Návrh na ustavení nebo volbu členů stálých komisí PS
# Ok
# 4
# 8
#  12. prosince 2017
# Návrh na volbu členů nebo ustavení SK GIBS
# Ok
# 4
# 9
#  12. prosince 2017
# Návrh na volbu členů nebo ustavení SK KPO
# Ok
# 4
# 10
#  12. prosince 2017
# Návrh na volbu členů nebo ustavení SK CEÚ
# Ok
# 4
# 11
#  12. prosince 2017
# Návrh na volbu členů nebo ustavení SK BIS
# Ok
# 4
# 12
#  12. prosince 2017
# Návrh na volbu členů nebo ustavení SK NBÚ
# Ok
# 4
# 13
#  12. prosince 2017
# Návrh na volbu členů nebo ustavení SK VZ
# Ok
# 4
# 14
#  12. prosince 2017
# Návrh na volbu členů nebo ustavení SK FAÚ
# Ok
# 4
#
# Cannot open page
# 4
# 16
#  12. prosince 2017
# Návrh na volbu členů do stálých delegací Parlamentu
# Ok
# 4
# 17
#  12. prosince 2017
# Návrh na volbu členů do stálých delegací Parlamentu
# Ok
# 4
# 18
#  12. prosince 2017
# Návrh na volbu členů do stálých delegací Parlamentu
# Ok
# 4
# 19
#  12. prosince 2017
# Návrh na volbu členů do stálých delegací Parlamentu
# Ok
# 4
# 20
#  12. prosince 2017
# Návrh na volbu členů do stálých delegací Parlamentu
# Ok
# 4
# 101
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 102
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 103
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 104
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 105
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 106
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 107
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 108
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 109
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 110
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 111
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 112
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 113
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 114
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 115
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 116
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 117
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 118
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 119
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 120
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 21
#  12. prosince 2017
# Návrh na volbu členů do stálých delegací Parlamentu
# Ok
# 4
# 22
#  12. prosince 2017
# Zpráva o plnění státního rozpočtu ČR za 1. pololetí 2017
# Ok
# 4
# 23
#  12. prosince 2017
# Zpr. o činnosti kontrolní rady GA ČR říjen 2016 - září 2017
# Ok
# 4
# 24
#  12. prosince 2017
# Zpr. o činnosti kontrolní rady GA ČR říjen 2016 - září 2017
# Ok
# 4
# 25
#  12. prosince 2017
# Zpráva o stavu zemědělství ČR za rok 2016
# Ok
# 4
# 26
#  12. prosince 2017
# Výroční zprávy a účetní závěrky zdr. pojišťoven za rok 2016
# Ok
# 4
# 27
#  12. prosince 2017
# Rozh. vl. o přeletech a průj.ozbroj.sil přes území ČR - 2018
# Ok
# 4
#
# Cannot open page
# 4
#
# Cannot open page
# 4
# 30
#  12. prosince 2017
# Novela z. o podmínkách podnikání v oblasti cestovního ruchu - EU
# Ok
# 4
# 31
#  12. prosince 2017
# Novela z. o podmínkách podnikání v oblasti cestovního ruchu - EU
# Ok
# 4
# 32
#  12. prosince 2017
# Změny přílohy III Rotterdamské úmluvy
# Ok
# 4
# 33
#  12. prosince 2017
# Návrh na zřízení Vyšetřovací komise Poslanecké sněmovny k OKD
# Ok
# 4
# 34
#  15. prosince 2017
# Pořad schůze
# Ok
# 4
# 35
#  15. prosince 2017
# Pořad schůze
# Ok
# 4
# 36
#  15. prosince 2017
# Návrh na změny ve složení orgánů Poslanecké sněmovny
# Ok
# 4
# 37
#  15. prosince 2017
# Návrh na změny ve složení orgánů Poslanecké sněmovny
# Ok
# 4
# 38
#  15. prosince 2017
# Návrh na změny ve složení orgánů Poslanecké sněmovny
# Ok
# 4
# 39
#  15. prosince 2017
# Návrh na potvrzení předsedy výboru PS
# Ok
# 4
# 40
#  19. prosince 2017
# Pořad schůze
# Ok
# 4
# 41
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 42
#  19. prosince 2017
# None
# Ok
# 4
# 43
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 44
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 45
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 46
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 47
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 48
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 49
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 50
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 51
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 52
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 53
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 54
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 55
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 56
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 57
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 58
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 59
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 4
# 60
#  19. prosince 2017
# Vl.n.z. o státním rozpočtu ČR na rok 2018
# Ok
# 5
# 1
#  10. ledna 2018
# Pořad schůze
# Ok
# 5
# 2
#  10. ledna 2018
# Pořad schůze
# Ok
# 5
# 3
#  10. ledna 2018
# Pořad schůze
# Ok
# 5
# 4
#  10. ledna 2018
# Žádost vlády České republiky o vyslovení důvěry
# Ok
# 5
# 5
#  10. ledna 2018
# Žádost vlády České republiky o vyslovení důvěry
# Ok
# 5
# 6
#  10. ledna 2018
# Žádost vlády České republiky o vyslovení důvěry
# Ok
# 5
# 7
#  16. ledna 2018
# None
# Ok
# 5
#
# Cannot open page
# 6
# 81
#  25. ledna 2018
# Zpráva o životním prostředí ČR 2016
# Ok
# 6
# 82
#  25. ledna 2018
# Účast ozbrojených sil ČR na vojenských cvičeních v roce 2018
# Ok
# 6
# 83
#  25. ledna 2018
# None
# Ok
# 6
# 84
#  26. ledna 2018
# Novela z. o léčivech - EU
# Ok
# 6
# 85
#  26. ledna 2018
# Novela z. o léčivech - EU
# Ok
# 6
# 86
#  26. ledna 2018
# Novela z. o léčivech - EU
# Ok
# 6
# 87
#  26. ledna 2018
# Novela z. o léčivech - EU
# Ok
# 6
# 88
#  26. ledna 2018
# Novela z. o léčivech - EU
# Ok
# 6
# 21
#  18. ledna 2018
# Novela z. o ochraně ovzduší - EU
# Ok
# 6
# 22
#  18. ledna 2018
# Novela z. o ochraně ovzduší - EU
# Ok
# 6
# 23
#  18. ledna 2018
# Novela z. o ochraně ovzduší - EU
# Ok
# 6
# 24
#  18. ledna 2018
# Novela z. o ochraně ovzduší - EU
# Ok
# 6
# 25
#  18. ledna 2018
# Novela z. o ochraně ovzduší - EU
# Ok
# 6
# 26
#  18. ledna 2018
# Novela z. o ochraně ovzduší - EU
# Ok
# 6
# 27
#  19. ledna 2018
# Pořad schůze
# Ok
# 6
# 28
#  19. ledna 2018
# Návrh na volbu členů nebo ustavení SK ÚZSI
# Ok
# 6
# 29
#  19. ledna 2018
# Žádost o vyslovení souhlasu s tr. stíháním poslanců
# Ok
# 6
# 30
#  19. ledna 2018
# Žádost o vyslovení souhlasu s tr. stíháním poslanců
# Ok
# 6
# 31
#  23. ledna 2018
# Pořad schůze
# Ok
# 6
# 32
#  23. ledna 2018
# Pořad schůze
# Ok
# 6
# 33
#  23. ledna 2018
# Pořad schůze
# Ok
# 6
# 34
#  23. ledna 2018
# Novela z. - zákoník práce
# Ok
# 6
# 35
#  23. ledna 2018
# Návrh Pravidel hospodaření poslaneckých klubů pro rok 2018
# Ok
# 6
# 36
#  23. ledna 2018
# Vl. n. z. o podmínkách využív. gen. zdrojů podle Nagoj. prot. - EU
# Ok
# 6
# 37
#  23. ledna 2018
# Vl. n. z. o podmínkách využív. gen. zdrojů podle Nagoj. prot. - EU
# Ok
# 6
# 38
#  23. ledna 2018
# Vl. n. z. o podmínkách využív. gen. zdrojů podle Nagoj. prot. - EU
# Ok
# 6
# 39
#  23. ledna 2018
# Vl. n. z. o podmínkách využív. gen. zdrojů podle Nagoj. prot. - EU
# Ok
# 6
# 40
#  23. ledna 2018
# Novela z. o evidenci obyvatel
# Ok
# 6
# 61
#  24. ledna 2018
# Žádost o vyslovení souhl. k trest. stíhání posl. Pavla Růžičky
# Ok
# 6
# 62
#  24. ledna 2018
# Žádost o vyslovení souhl. k trest. stíhání posl. Pavla Růžičky
# Ok
# 6
# 63
#  24. ledna 2018
# Novela z. o provozu na pozemních komunikacích - EU
# Ok
# 6
# 64
#  24. ledna 2018
# Novela z. o ČNB
# Ok
# 6
# 65
#  24. ledna 2018
# Novela z. o ČNB
# Ok
# 6
# 66
#  24. ledna 2018
# Novela z. o ČNB
# Ok
# 6
# 67
#  24. ledna 2018
# Novela z. - daňový řád - EU
# Ok
# 6
# 68
#  25. ledna 2018
# None
# Ok
# 6
# 69
#  25. ledna 2018
# Pořad schůze
# Ok
# 6
# 70
#  25. ledna 2018
# Sml. mezi ČR a Vietnamem o spolupráci proti tr. činnosti
# Ok
# 6
# 71
#  25. ledna 2018
# Dodatkový protokol k Trestněprávní úmluvě o korupci
# Ok
# 6
# 72
#  25. ledna 2018
# Dohoda mezi ČR a Japonskem o vízech k prac. dovolené
# Ok
# 6
# 73
#  25. ledna 2018
# Novela z. - daňový řád - EU
# Ok
# 6
# 74
#  25. ledna 2018
# Novela z. - daňový řád - EU
# Ok
# 6
# 75
#  25. ledna 2018
# Novela z. - daňový řád - EU
# Ok
# 6
# 76
#  25. ledna 2018
# Vl.n.z. o distribuci pojištění a zajištění - EU
# Ok
# 6
# 77
#  25. ledna 2018
# Vl.n.z. v souv. s přij. zák. o distrib. pojiš. a zajiš.
# Ok
# 6
# 78
#  25. ledna 2018
# Vl.n.z. v souv. s přij. zák. o distrib. pojiš. a zajiš.
# Ok
# 6
# 79
#  25. ledna 2018
# Vl.n.z. v souv. s přij. zák. o distrib. pojiš. a zajiš.
# Ok
# 6
# 80
#  25. ledna 2018
# Vl.n.z. v souv. s přij. zák. o distrib. pojiš. a zajiš.
# Ok
# 6
# 41
#  23. ledna 2018
# Novela z. o evidenci obyvatel
# Ok
# 6
# 42
#  23. ledna 2018
# Novela z. o evidenci obyvatel
# Ok
# 6
# 43
#  23. ledna 2018
# N.z., kterým se ruší zák. opatření Senátu č. 340/2013 Sb.
# Ok
# 6
# 44
#  23. ledna 2018
# N.z., kterým se ruší zákon o prodejní době
# Ok
# 6
# 45
#  23. ledna 2018
# N.z., kterým se zrušuje zákon o elektronické evidenci tržeb
# Ok
# 6
# 46
#  23. ledna 2018
# N.z., kterým se zrušuje zákon o elektronické evidenci tržeb
# Ok
# 6
# 47
#  23. ledna 2018
# N.z., kterým se zrušuje zákon o elektronické evidenci tržeb
# Ok
# 6
# 48
#  24. ledna 2018
# Novela z. o zajišťování obrany ČR
# Ok
# 6
# 49
#  24. ledna 2018
# N.z. o změně zákonů uprav.počet členů zvl.kontrol.orgánů PS
# Ok
# 6
# 50
#  24. ledna 2018
# N.z. o změně zákonů uprav.počet členů zvl.kontrol.orgánů PS
# Ok
# 6
# 51
#  24. ledna 2018
# Novela z. - vodní zákon - EU
# Ok
# 6
# 52
#  24. ledna 2018
# Novela z. - vodní zákon - EU
# Ok
# 6
# 53
#  24. ledna 2018
# Novela z. - vodní zákon - EU
# Ok
# 6
#
# Cannot open page
# 6
# 55
#  24. ledna 2018
# Návrh na odvolání členů DR VZP
# Ok
# 6
# 56
#  24. ledna 2018
# Návrh na volbu členů SR VZP
# Ok
# 6
# 57
#  24. ledna 2018
# Návrh na volbu členů DR VZP
# Ok
# 6
# 58
#  24. ledna 2018
# Novela z. o léčivech
# Ok
# 6
# 59
#  24. ledna 2018
# Žádost o vyslovení souhlasu PS k trestnímu stíhání poslance
# Ok
# 6
# 60
#  24. ledna 2018
# None
# Ok
# 6
# 1
#  17. ledna 2018
# None
# Ok
# 6
# 2
#  17. ledna 2018
# Pořad schůze
# Ok
# 6
# 3
#  17. ledna 2018
# Pořad schůze
# Ok
# 6
# 4
#  17. ledna 2018
# Pořad schůze
# Ok
# 6
# 5
#  17. ledna 2018
# Pořad schůze
# Ok
# 6
# 6
#  17. ledna 2018
# Pořad schůze
# Ok
# 6
# 7
#  17. ledna 2018
# Pořad schůze
# Ok
# 6
# 8
#  17. ledna 2018
# Pořad schůze
# Ok
# 6
# 9
#  17. ledna 2018
# Pořad schůze
# Ok
# 6
# 10
#  17. ledna 2018
# Pořad schůze
# Ok
# 6
# 11
#  17. ledna 2018
# Pořad schůze
# Ok
# 6
# 12
#  17. ledna 2018
# Návrh na zřízení SK pro kontrolu činnosti ÚZS
# Ok
# 6
# 13
#  17. ledna 2018
# Návrh na volbu členů Národní rozpočtové rady
# Ok
# 6
# 14
#  17. ledna 2018
# Návrh na volbu členů Nejvyššího kontrolního úřadu
# Ok
# 6
# 15
#  17. ledna 2018
# Změna azylové politiky EU a revize tzv. Dublinského protokolu
# Ok
# 6
# 16
#  17. ledna 2018
# Změna azylové politiky EU a revize tzv. Dublinského protokolu
# Ok
# 6
# 17
#  18. ledna 2018
# Pořad schůze
# Ok
# 6
# 18
#  18. ledna 2018
# Pořad schůze
# Ok
# 6
# 19
#  18. ledna 2018
# Novela z. o léčivech - EU
# Ok
# 6
# 20
#  18. ledna 2018
# Novela z. o ochraně ovzduší - EU
# Ok
# 7
# 61
#  7. března 2018
# Zpráva o inflaci - leden 2018
# Ok
# 7
# 62
#  7. března 2018
# Novela z. o evidenci tržeb
# Ok
# 7
# 63
#  7. března 2018
# Novela z. o evidenci tržeb
# Ok
# 7
# 64
#  7. března 2018
# Novela z. o Kanceláři prezidenta republiky
# Ok
# 7
# 65
#  7. března 2018
# Novela z. o Kanceláři prezidenta republiky
# Ok
# 7
# 66
#  7. března 2018
# Novela z. o svobodném přístupu k informacím
# Ok
# 7
# 67
#  7. března 2018
# Novela z. o svobodném přístupu k informacím
# Ok
# 7
# 68
#  7. března 2018
# Novela z. o svobodném přístupu k informacím
# Ok
# 7
# 69
#  7. března 2018
# Novela z. o svobodném přístupu k informacím
# Ok
# 7
# 70
#  7. března 2018
# Novela z. o svobodném přístupu k informacím
# Ok
# 7
# 71
#  7. března 2018
# Novela z. o svobodném přístupu k informacím
# Ok
# 7
# 72
#  7. března 2018
# Novela z. o svobodném přístupu k informacím
# Ok
# 7
# 73
#  7. března 2018
# Novela z. o svobodném přístupu k informacím
# Ok
# 7
# 74
#  7. března 2018
# Novela z. o svobodném přístupu k informacím
# Ok
# 7
# 75
#  7. března 2018
# Návrh na volbu členů Rady Státního fondu kultury ČR
# Ok
# 7
# 76
#  20. března 2018
# Pořad schůze
# Ok
# 7
# 77
#  20. března 2018
# Pořad schůze
# Ok
# 7
# 78
#  20. března 2018
# Pořad schůze
# Ok
# 7
# 79
#  20. března 2018
# Pořad schůze
# Ok
# 7
# 80
#  20. března 2018
# Pořad schůze
# Ok
# 7
# 21
#  28. února 2018
# Návrh na volbu členů DR VZP
# Ok
# 7
# 22
#  28. února 2018
# Návrh na volbu členů Rady České tiskové kanceláře
# Ok
# 7
# 23
#  28. února 2018
# Návrh na volbu členů Rady Státního fondu kultury ČR
# Ok
# 7
# 24
#  28. února 2018
# Novela z. o střetu zájmů
# Ok
# 7
# 25
#  28. února 2018
# Novela z. o střetu zájmů
# Ok
# 7
# 26
#  28. února 2018
# Novela z. o střetu zájmů
# Ok
# 7
# 27
#  28. února 2018
# Novela z. o střetu zájmů
# Ok
# 7
# 28
#  28. února 2018
# Novela z. o střetu zájmů
# Ok
# 7
#
# Cannot open page
# 7
# 30
#  28. února 2018
# None
# Ok
# 7
# 31
#  28. února 2018
# None
# Ok
# 7
# 32
#  28. února 2018
# None
# Ok
# 7
# 33
#  28. února 2018
# None
# Ok
# 7
# 34
#  28. února 2018
# None
# Ok
# 7
# 35
#  1. března 2018
# Písemná interpelace V. Munzara na A. Schillerovou ve věci interpelace
# Ok
# 7
# 36
#  1. března 2018
# Písemná interpelace Z. Stanjury na D. Ťoka ve věci stavby I/11 Prodlo
# Ok
# 7
# 37
#  1. března 2018
# Písemná interpelace Z. Stanjury na D. Ťoka ve věci aktuálního stavu vý
# Ok
# 7
# 38
#  1. března 2018
# Pořad schůze
# Ok
# 7
# 39
#  1. března 2018
# Pořad schůze
# Ok
# 7
# 40
#  1. března 2018
# Novela z. - trestní zákoník
# Ok
# 7
# 141
#  21. března 2018
# Sml. mezi ČR a Ghanou o zamezení dvojímu zdanění
# Ok
# 7
# 142
#  21. března 2018
# Změny příloh A a C Stockholmské úmluvy
# Ok
# 7
# 143
#  21. března 2018
# Změny příloh A a C Stockholmské úmluvy
# Ok
# 7
# 144
#  21. března 2018
# Sml.o stabilitě, koordinaci a správě v hosp. a měnové unii
# Ok
# 7
# 145
#  21. března 2018
# Návrh státního závěrečného účtu ČR za rok 2016
# Ok
# 7
# 146
#  21. března 2018
# Návrh státního závěrečného účtu ČR za rok 2016
# Ok
# 7
# 147
#  21. března 2018
# Zpráva o vývoji malého a středního podnikání v roce 2016
# Ok
# 7
# 148
#  21. března 2018
# Výroční zpráva o hospodaření Českého rozhlasu za rok 2015
# Ok
# 7
# 149
#  21. března 2018
# Výroční zpráva o hospodaření Českého rozhlasu za rok 2015
# Ok
# 7
# 150
#  21. března 2018
# Výroční zpráva o hospodaření Českého rozhlasu za rok 2016
# Ok
# 7
# 151
#  21. března 2018
# Výroční zpráva o činnosti Českého rozhlasu za rok 2016
# Ok
# 7
# 152
#  21. března 2018
# Zpráva o peticích za období od 1. 7. 2017 do 31. 12. 2017
# Ok
# 7
# 153
#  21. března 2018
# None
# Ok
# 7
# 81
#  20. března 2018
# Pořad schůze
# Ok
# 7
# 82
#  20. března 2018
# Pořad schůze
# Ok
# 7
# 83
#  20. března 2018
# Pořad schůze
# Ok
# 7
# 84
#  20. března 2018
# Pořad schůze
# Ok
# 7
# 85
#  20. března 2018
# Novela z. o Ústavním soudu
# Ok
# 7
# 86
#  20. března 2018
# Novela z. o evidenci tržeb
# Ok
# 7
# 87
#  20. března 2018
# Novela z. o převodu vlastnického práva
# Ok
# 7
# 88
#  20. března 2018
# Novela z. o převodu vlastnického práva
# Ok
# 7
# 89
#  20. března 2018
# Novela z. o mezinárodní justiční spolupráci ve věcech trest. - EU
# Ok
# 7
# 90
#  20. března 2018
# Novela z. o mezinárodní justiční spolupráci ve věcech trest. - EU
# Ok
# 7
# 91
#  20. března 2018
# Novela z. o mezinárodní justiční spolupráci ve věcech trest. - EU
# Ok
# 7
# 92
#  20. března 2018
# Vl.n.z.o poskyt.st.záruky ČR na zajištění půjčky ČNB pro MMF
# Ok
# 7
# 93
#  20. března 2018
# N. z. o činnosti inst. zaměstnaneckého penzijního pojištění - EU
# Ok
# 7
#
# Cannot open page
# 7
#
# Cannot open page
# 7
# 96
#  20. března 2018
# Novela z. o vývozu a dovozu zboží - EU
# Ok
# 7
# 97
#  20. března 2018
# Novela z. - insolvenční zákon - EU
# Ok
# 7
# 98
#  20. března 2018
# Novela z. - insolvenční zákon - EU
# Ok
# 7
# 99
#  20. března 2018
# Novela z. - insolvenční zákon - EU
# Ok
# 7
# 100
#  20. března 2018
# Novela z. - insolvenční zákon - EU
# Ok
# 7
# 41
#  1. března 2018
# Novela z. - trestní zákoník
# Ok
# 7
# 42
#  2. března 2018
# Pořad schůze
# Ok
# 7
# 43
#  2. března 2018
# Pořad schůze
# Ok
# 7
# 44
#  2. března 2018
# Návrh na volbu předsedy SK pro kontrolu činnosti GIBS
# Ok
# 7
# 45
#  2. března 2018
# Novela z. - správní řád
# Ok
# 7
# 46
#  2. března 2018
# Novela z. - správní řád
# Ok
# 7
# 47
#  2. března 2018
# Novela z. o volbách do Parlamentu ČR
# Ok
# 7
# 48
#  2. března 2018
# Novela z. o volbách do Parlamentu ČR
# Ok
# 7
# 49
#  2. března 2018
# Novela z. o volbách do Parlamentu ČR
# Ok
# 7
# 50
#  2. března 2018
# Novela z. o volbách do Parlamentu ČR
# Ok
# 7
# 51
#  6. března 2018
# Pořad schůze
# Ok
# 7
# 52
#  6. března 2018
# Pořad schůze
# Ok
# 7
# 53
#  6. března 2018
# Pořad schůze
# Ok
# 7
# 54
#  6. března 2018
# Novela ústav. z. - Ústava ČR
# Ok
# 7
# 55
#  6. března 2018
# Novela ústav. z. - Ústava ČR
# Ok
# 7
# 56
#  6. března 2018
# Novela ústav. z. - Ústava ČR
# Ok
# 7
# 57
#  6. března 2018
# Novela ústav. z. - Ústava ČR
# Ok
# 7
# 58
#  6. března 2018
# Novela z. o urychlení výstavby dopravní infrastruktury
# Ok
# 7
# 59
#  6. března 2018
# Novela z. o urychlení výstavby dopravní infrastruktury
# Ok
# 7
# 60
#  6. března 2018
# Novela z. o urychlení výstavby dopravní infrastruktury
# Ok
# 7
# 1
#  27. února 2018
# None
# Ok
# 7
# 2
#  27. února 2018
# Pořad schůze
# Ok
# 7
# 3
#  27. února 2018
# Pořad schůze
# Ok
# 7
# 4
#  27. února 2018
# Pořad schůze
# Ok
# 7
# 5
#  27. února 2018
# Pořad schůze
# Ok
# 7
# 6
#  27. února 2018
# Pořad schůze
# Ok
# 7
# 7
#  27. února 2018
# Novela z. o podmínkách podnikání v oblasti cestovního ruchu - EU
# Ok
# 7
# 8
#  27. února 2018
# Novela z. - daňový řád - EU
# Ok
# 7
# 9
#  27. února 2018
# N.z. o celostátním referendu
# Ok
# 7
# 10
#  28. února 2018
# Pořad schůze
# Ok
# 7
# 11
#  28. února 2018
# Novela z. o daních z příjmů
# Ok
# 7
# 12
#  28. února 2018
# Novela z. o obcích
# Ok
# 7
# 13
#  28. února 2018
# Novela z. o majetkovém vyrovnání s církvemi
# Ok
# 7
# 14
#  28. února 2018
# Novela z. o majetkovém vyrovnání s církvemi
# Ok
# 7
# 15
#  28. února 2018
# Novela z. o majetkovém vyrovnání s církvemi
# Ok
# 7
# 16
#  28. února 2018
# Novela z. o majetkovém vyrovnání s církvemi
# Ok
# 7
# 17
#  28. února 2018
# Novela z. o majetkovém vyrovnání s církvemi
# Ok
# 7
# 18
#  28. února 2018
# Novela z. - trestní zákoník
# Ok
# 7
# 19
#  28. února 2018
# Návrh na změny ve složení orgánů Poslanecké sněmovny
# Ok
# 7
# 20
#  28. února 2018
# Návrh na změny ve složení orgánů Poslanecké sněmovny
# Ok
# 7
# 121
#  21. března 2018
# Návrh na volbu členů Rady Státního fondu kinematografie
# Ok
# 7
# 122
#  21. března 2018
# Novela z. - zákoník práce
# Ok
# 7
# 123
#  21. března 2018
# Novela z. - zákoník práce
# Ok
# 7
# 124
#  21. března 2018
# Novela z. - zákoník práce
# Ok
# 7
# 125
#  21. března 2018
# Novela z. o dluhopisech
# Ok
# 7
# 126
#  21. března 2018
# Novela z. o ozdravných postupech - EU
# Ok
# 7
# 127
#  21. března 2018
# Novela z. o hornické činnosti - EU
# Ok
# 7
# 128
#  21. března 2018
# Novela z. o hornické činnosti - EU
# Ok
# 7
# 129
#  21. března 2018
# Změny přílohy III Rotterdamské úmluvy
# Ok
# 7
# 130
#  21. března 2018
# Sml. mezi ČR a Rep. Kosovo o zamezení dvojímu zdanění
# Ok
# 7
# 131
#  21. března 2018
# Sml. mezi ČR a Rep. Kosovo o zamezení dvojímu zdanění
# Ok
# 7
# 132
#  21. března 2018
# Sml. mezi ČR a Rep. Kosovo o zamezení dvojímu zdanění
# Ok
# 7
# 133
#  21. března 2018
# Sml. mezi ČR a Rep. Kosovo o zamezení dvojímu zdanění
# Ok
# 7
# 134
#  21. března 2018
# Sml. mezi ČR a Rep. Kosovo o zamezení dvojímu zdanění
# Ok
# 7
# 135
#  21. března 2018
# Sml.mezi ČR a vl.Rep.Kazachstán o spol.v boji proti tr.činn.
# Ok
# 7
# 136
#  21. března 2018
# Sml.mezi ČR a Vietnamem o předávání odsouzených osob
# Ok
# 7
# 137
#  21. března 2018
# Úml.Rady Evropy o komp.příst.k ochraně,bezp.při sport.akcích
# Ok
# 7
# 138
#  21. března 2018
# Rámcová dohoda mezi EU a Austrálií
# Ok
# 7
# 139
#  21. března 2018
# Dodat. prot. k Úmluvě o lidských právech a biomedicíně
# Ok
# 7
# 140
#  21. března 2018
# Sml. mezi ČR a Ghanou o zamezení dvojímu zdanění
# Ok
# 7
# 101
#  20. března 2018
# Novela z. - insolvenční zákon - EU
# Ok
# 7
# 102
#  20. března 2018
# Novela z. - insolvenční zákon - EU
# Ok
# 7
# 103
#  20. března 2018
# Novela z. - insolvenční zákon - EU
# Ok
# 7
# 104
#  20. března 2018
# Novela z. - trestní zákoník - EU
# Ok
# 7
# 105
#  20. března 2018
# Novela z. - trestní zákoník - EU
# Ok
# 7
# 106
#  20. března 2018
# Novela z. - trestní zákoník - EU
# Ok
# 7
# 107
#  20. března 2018
# Novela z. - trestní zákoník - EU
# Ok
# 7
# 108
#  21. března 2018
# Novela z. o ČNB
# Ok
# 7
# 109
#  21. března 2018
# Novela z. o ČNB
# Ok
# 7
# 110
#  21. března 2018
# Novela z. - daňový řád - EU
# Ok
# 7
# 111
#  21. března 2018
# Novela z. - daňový řád - EU
# Ok
# 7
# 112
#  21. března 2018
# Novela z. - daňový řád - EU
# Ok
# 7
# 113
#  21. března 2018
# Novela z. - daňový řád - EU
# Ok
# 7
# 114
#  21. března 2018
# Novela z. - daňový řád - EU
# Ok
# 7
# 115
#  21. března 2018
# Novela z. - daňový řád - EU
# Ok
# 7
# 116
#  21. března 2018
# Novela z. - daňový řád - EU
# Ok
# 7
# 117
#  21. března 2018
# Novela z. - daňový řád - EU
# Ok
# 7
# 118
#  21. března 2018
# Novela z. o organizaci a provádění sociálního zabezpečení
# Ok
# 7
# 119
#  21. března 2018
# Novela z. o organizaci a provádění sociálního zabezpečení
# Ok
# 7
# 120
#  21. března 2018
# Novela z. - zákoník práce
# Ok
# 8
# 1
#  9. března 2018
# None
# Ok
# 8
# 2
#  9. března 2018
# None
# Ok
# 8
# 3
#  9. března 2018
# Pořad schůze
# Ok
# 9
# 1
#  7. března 2018
# None
# Ok
# 9
# 2
#  7. března 2018
# Pořad schůze
# Ok
# 9
# 3
#  7. března 2018
# Pořad schůze
# Ok
# 9
# 4
#  7. března 2018
# Pořad schůze
# Ok
# 11
# 1
#  27. března 2018
# None
# Ok
# 11
# 2
#  27. března 2018
# Pořad schůze
# Ok
# 11
# 3
#  27. března 2018
# Pořad schůze
# Ok
# 11
# 4
#  27. března 2018
# Pořad schůze
# Ok
# 12
# 41
#  11. dubna 2018
# Novela z. o daních z příjmů
# Ok
# 12
# 42
#  12. dubna 2018
# Písemná interpelace J. Michálka na A. Babiše ve věci neutěšených platů
# Ok
# 12
# 43
#  12. dubna 2018
# Novela z. o daních z příjmů
# Ok
# 12
# 44
#  12. dubna 2018
# Novela z. o daních z příjmů
# Ok
# 12
# 45
#  12. dubna 2018
# Novela z. o směnárenské činnosti
# Ok
# 12
#
# Cannot open page
# 12
# 47
#  12. dubna 2018
# Novela z. o směnárenské činnosti
# Ok
# 12
# 48
#  12. dubna 2018
# Novela z. o směnárenské činnosti
# Ok
# 12
# 49
#  12. dubna 2018
# Novela z. o směnárenské činnosti
# Ok
# 12
# 50
#  12. dubna 2018
# Novela z. o některých přestupcích
# Ok
# 12
# 51
#  13. dubna 2018
# Pořad schůze
# Ok
# 12
# 52
#  13. dubna 2018
# Pořad schůze
# Ok
# 12
#
# Cannot open page
# 12
# 54
#  13. dubna 2018
# Novela z. o podmínkách podnikání v oblasti cestovního ruchu - EU
# Ok
# 12
# 55
#  13. dubna 2018
# Novela z. o podmínkách podnikání v oblasti cestovního ruchu - EU
# Ok
# 12
# 56
#  13. dubna 2018
# Novela z. o podmínkách podnikání v oblasti cestovního ruchu - EU
# Ok
# 12
# 57
#  13. dubna 2018
# Novela z. o podmínkách podnikání v oblasti cestovního ruchu - EU
# Ok
# 12
# 58
#  13. dubna 2018
# Novela z. o nemocenském pojištění
# Ok
# 12
# 59
#  13. dubna 2018
# Novela z. o nemocenském pojištění
# Ok
# 12
# 60
#  13. dubna 2018
# Novela z. o nemocenském pojištění
# Ok
# 12
# 81
#  17. dubna 2018
# Pozice vlády České republiky k událostem v Sýrii
# Ok
# 12
# 82
#  17. dubna 2018
# Novela z. o volbách do Parlamentu ČR
# Ok
# 12
# 83
#  17. dubna 2018
# Novela z. o volbách do Parlamentu ČR
# Ok
# 12
# 84
#  17. dubna 2018
# Novela z. o státním zastupitelství
# Ok
# 12
# 85
#  17. dubna 2018
# Novela z. o státním zastupitelství
# Ok
# 12
# 86
#  17. dubna 2018
# N.z. o celostátním referendu
# Ok
# 12
# 87
#  18. dubna 2018
# None
# Ok
# 12
# 88
#  18. dubna 2018
# None
# Ok
# 12
# 89
#  18. dubna 2018
# Návrh na volbu člena Dozorčí rady Státního fondu rozvoje bydlení
# Ok
# 12
# 90
#  18. dubna 2018
# Návrh na volbu členů DR Státního fondu dopravní infrastruktury
# Ok
# 12
# 91
#  18. dubna 2018
# Vl.n.z. o zpracování osobních údajů - EU
# Ok
# 12
# 92
#  18. dubna 2018
# Vl.n.z. o zpracování osobních údajů - EU
# Ok
# 12
# 93
#  18. dubna 2018
# Vl.n.z. o zpracování osobních údajů - EU
# Ok
# 12
# 94
#  18. dubna 2018
# Vl.n.z. o zpracování osobních údajů - EU
# Ok
# 12
# 95
#  18. dubna 2018
# Vl.n.z. o zpracování osobních údajů - EU
# Ok
# 12
# 96
#  18. dubna 2018
# Vl.n.z. o zpracování osobních údajů - EU
# Ok
# 12
# 97
#  18. dubna 2018
# Vl.n.z. o zpracování osobních údajů - související - EU
# Ok
# 12
# 98
#  18. dubna 2018
# Vl.n.z. o zpracování osobních údajů - související - EU
# Ok
# 12
# 99
#  18. dubna 2018
# Vl.n.z. o zpracování osobních údajů - související - EU
# Ok
# 12
# 100
#  18. dubna 2018
# Vl.n.z. o zpracování osobních údajů - související - EU
# Ok
# 12
# 61
#  13. dubna 2018
# Novela z. - občanský soudní řád
# Ok
# 12
# 62
#  13. dubna 2018
# Novela z. o pomoci v hmotné nouzi
# Ok
# 12
# 63
#  13. dubna 2018
# Novela z. o pomoci v hmotné nouzi
# Ok
# 12
# 64
#  13. dubna 2018
# Novela z. o pomoci v hmotné nouzi
# Ok
# 12
#
# Cannot open page
# 12
# 66
#  13. dubna 2018
# Novela z. o volbách do Parlamentu ČR
# Ok
# 12
# 67
#  17. dubna 2018
# Pořad schůze
# Ok
# 12
# 68
#  17. dubna 2018
# Pořad schůze
# Ok
# 12
# 69
#  17. dubna 2018
# Pořad schůze
# Ok
# 12
# 70
#  17. dubna 2018
# Pořad schůze
# Ok
# 12
# 71
#  17. dubna 2018
# Pořad schůze
# Ok
# 12
# 72
#  17. dubna 2018
# Pořad schůze
# Ok
# 12
# 73
#  17. dubna 2018
# Pozice vlády České republiky k událostem v Sýrii
# Ok
# 12
# 74
#  17. dubna 2018
# Pozice vlády České republiky k událostem v Sýrii
# Ok
# 12
# 75
#  17. dubna 2018
# Pozice vlády České republiky k událostem v Sýrii
# Ok
# 12
# 76
#  17. dubna 2018
# Pozice vlády České republiky k událostem v Sýrii
# Ok
# 12
# 77
#  17. dubna 2018
# Pozice vlády České republiky k událostem v Sýrii
# Ok
# 12
# 78
#  17. dubna 2018
# Pozice vlády České republiky k událostem v Sýrii
# Ok
# 12
# 79
#  17. dubna 2018
# Pozice vlády České republiky k událostem v Sýrii
# Ok
# 12
# 80
#  17. dubna 2018
# Pozice vlády České republiky k událostem v Sýrii
# Ok
# 12
# 21
#  11. dubna 2018
# Novela z. - vodní zákon - EU
# Ok
# 12
# 22
#  11. dubna 2018
# Novela z. - vodní zákon - EU
# Ok
# 12
# 23
#  11. dubna 2018
# Novela z. - vodní zákon - EU
# Ok
# 12
# 24
#  11. dubna 2018
# Novela z. - vodní zákon - EU
# Ok
# 12
# 25
#  11. dubna 2018
# Novela z. - vodní zákon - EU
# Ok
# 12
# 26
#  11. dubna 2018
# Novela z. - vodní zákon - EU
# Ok
# 12
# 27
#  11. dubna 2018
# Novela z. - vodní zákon - EU
# Ok
# 12
# 28
#  11. dubna 2018
# Novela z. - vodní zákon - EU
# Ok
# 12
# 29
#  11. dubna 2018
# Novela z. - vodní zákon - EU
# Ok
# 12
# 30
#  11. dubna 2018
# Návrh na změny ve složení orgánů Poslanecké sněmovny
# Ok
# 12
# 31
#  11. dubna 2018
# Návrh na změny ve složení orgánů Poslanecké sněmovny
# Ok
# 12
# 32
#  11. dubna 2018
# Novela z. - školský zákon
# Ok
# 12
# 33
#  11. dubna 2018
# Novela z. - školský zákon
# Ok
# 12
# 34
#  11. dubna 2018
# Novela z. - školský zákon
# Ok
# 12
# 35
#  11. dubna 2018
# Novela z. - školský zákon
# Ok
# 12
# 36
#  11. dubna 2018
# Novela z. - školský zákon
# Ok
# 12
# 37
#  11. dubna 2018
# Novela ústav. z. - Ústava ČR
# Ok
# 12
# 38
#  11. dubna 2018
# Novela z. o majetku České republiky
# Ok
# 12
# 39
#  11. dubna 2018
# Novela z. o majetku České republiky
# Ok
# 12
# 40
#  11. dubna 2018
# Novela z. - trestní řád
# Ok
# 12
# 101
#  18. dubna 2018
# Vl.n.z. o zpracování osobních údajů - související - EU
# Ok
# 12
# 102
#  18. dubna 2018
# Vl.n.z. o zpracování osobních údajů - související - EU
# Ok
# 12
# 103
#  18. dubna 2018
# Novela z. - školský zákon
# Ok
# 12
# 104
#  18. dubna 2018
# N.z.o zrušení zákona o zákazu dodávek pro jader. el. Búšehr
# Ok
# 12
#
# Cannot open page
# 12
# 106
#  18. dubna 2018
# N.z.o zrušení zákona o zákazu dodávek pro jader. el. Búšehr
# Ok
# 12
#
# Cannot open page
# 12
# 108
#  18. dubna 2018
# N.z.o zrušení zákona o zákazu dodávek pro jader. el. Búšehr
# Ok
# 12
# 109
#  19. dubna 2018
# N.z.o zrušení zákona o zákazu dodávek pro jader. el. Búšehr
# Ok
# 12
# 110
#  19. dubna 2018
# N.z.o zrušení zákona o zákazu dodávek pro jader. el. Búšehr
# Ok
# 12
# 111
#  19. dubna 2018
# N.z.o zrušení zákona o zákazu dodávek pro jader. el. Búšehr
# Ok
# 12
# 112
#  19. dubna 2018
# N.z.o zrušení zákona o zákazu dodávek pro jader. el. Búšehr
# Ok
# 12
# 113
#  19. dubna 2018
# N.z.o zrušení zákona o zákazu dodávek pro jader. el. Búšehr
# Ok
# 12
# 114
#  19. dubna 2018
# N.z.o zrušení zákona o zákazu dodávek pro jader. el. Búšehr
# Ok
# 12
# 115
#  19. dubna 2018
# N.z.o zrušení zákona o zákazu dodávek pro jader. el. Búšehr
# Ok
# 12
# 116
#  19. dubna 2018
# N.z.o zrušení zákona o zákazu dodávek pro jader. el. Búšehr
# Ok
# 12
# 117
#  19. dubna 2018
# N.z.o zrušení zákona o zákazu dodávek pro jader. el. Búšehr
# Ok
# 12
# 118
#  19. dubna 2018
# Novela z. o důchodovém pojištění
# Ok
# 12
# 119
#  19. dubna 2018
# Novela z. o důchodovém pojištění
# Ok
# 12
# 120
#  19. dubna 2018
# Novela z. o důchodovém pojištění
# Ok
# 12
# 121
#  19. dubna 2018
# Novela z. o zrušení Fondu národního majetku
# Ok
# 12
# 122
#  19. dubna 2018
# Novela z. o zrušení Fondu národního majetku
# Ok
# 12
# 123
#  19. dubna 2018
# Novela z. o zrušení Fondu národního majetku
# Ok
# 12
# 124
#  20. dubna 2018
# Pořad schůze
# Ok
# 12
# 125
#  20. dubna 2018
# Vl. n. z. o podmínkách využív. gen. zdrojů podle Nagoj. prot. - EU
# Ok
# 12
# 126
#  20. dubna 2018
# Vl. n. z. o podmínkách využív. gen. zdrojů podle Nagoj. prot. - EU
# Ok
# 12
# 127
#  20. dubna 2018
# Vl. n. z. o podmínkách využív. gen. zdrojů podle Nagoj. prot. - EU
# Ok
# 12
# 128
#  20. dubna 2018
# Novela z. o střetu zájmů
# Ok
# 12
# 129
#  20. dubna 2018
# Novela z. o střetu zájmů
# Ok
# 12
# 130
#  20. dubna 2018
# Novela z. o střetu zájmů
# Ok
# 12
# 131
#  20. dubna 2018
# Novela z. o střetu zájmů
# Ok
# 12
# 132
#  20. dubna 2018
# Novela z. o střetu zájmů
# Ok
# 12
# 133
#  20. dubna 2018
# Novela z. o střetu zájmů
# Ok
# 12
# 134
#  20. dubna 2018
# Novela z. o střetu zájmů
# Ok
# 12
# 135
#  20. dubna 2018
# Novela z. o poskytování dávek osobám se zdravot. postižením
# Ok
# 12
# 136
#  20. dubna 2018
# Novela z. o poskytování dávek osobám se zdravot. postižením
# Ok
# 12
# 137
#  20. dubna 2018
# Novela z. o poskytování dávek osobám se zdravot. postižením
# Ok
# 12
# 138
#  20. dubna 2018
# None
# Ok
# 12
# 139
#  20. dubna 2018
# Novela z. o státní službě
# Ok
# 12
# 140
#  20. dubna 2018
# Vl.n.z, kterým se mění volební zákony a soudní řád správní
# Ok
# 12
# 1
#  10. dubna 2018
# None
# Ok
# 12
#
# Cannot open page
# 12
# 3
#  10. dubna 2018
# Pořad schůze
# Ok
# 12
# 4
#  10. dubna 2018
# Pořad schůze
# Ok
# 12
# 5
#  10. dubna 2018
# Pořad schůze
# Ok
# 12
# 6
#  10. dubna 2018
# Pořad schůze
# Ok
# 12
# 7
#  10. dubna 2018
# Novela z. o střetu zájmů
# Ok
# 12
# 8
#  10. dubna 2018
# Vl. n. z. o podmínkách využív. gen. zdrojů podle Nagoj. prot. - EU
# Ok
# 12
# 9
#  10. dubna 2018
# Vl. n. z. o podmínkách využív. gen. zdrojů podle Nagoj. prot. - EU
# Ok
# 12
# 10
#  11. dubna 2018
# Novela z. - vodní zákon - EU
# Ok
# 12
# 11
#  11. dubna 2018
# Novela z. - vodní zákon - EU
# Ok
# 12
# 12
#  11. dubna 2018
# Novela z. - vodní zákon - EU
# Ok
# 12
# 13
#  11. dubna 2018
# Novela z. - vodní zákon - EU
# Ok
# 12
# 14
#  11. dubna 2018
# Novela z. - vodní zákon - EU
# Ok
# 12
# 15
#  11. dubna 2018
# Novela z. - vodní zákon - EU
# Ok
# 12
# 16
#  11. dubna 2018
# Novela z. - vodní zákon - EU
# Ok
# 12
# 17
#  11. dubna 2018
# Novela z. - vodní zákon - EU
# Ok
# 12
# 18
#  11. dubna 2018
# Novela z. - vodní zákon - EU
# Ok
# 12
# 19
#  11. dubna 2018
# Novela z. - vodní zákon - EU
# Ok
# 12
# 20
#  11. dubna 2018
# Novela z. - vodní zákon - EU
# Ok
# 12
# 141
#  20. dubna 2018
# Vl.n.z, kterým se mění volební zákony a soudní řád správní
# Ok
# 12
# 142
#  20. dubna 2018
# Vl.n.z, kterým se mění volební zákony a soudní řád správní
# Ok
# 12
# 143
#  20. dubna 2018
# None
# Ok
# 13
# 81
#  25. května 2018
# Návrhy Poslanecké sněmovny na propůjčení nebo udělení státních vyzname
# Ok
# 13
# 82
#  25. května 2018
# Návrhy Poslanecké sněmovny na propůjčení nebo udělení státních vyzname
# Ok
# 13
# 83
#  25. května 2018
# Návrhy Poslanecké sněmovny na propůjčení nebo udělení státních vyzname
# Ok
# 13
# 84
#  25. května 2018
# Návrhy Poslanecké sněmovny na propůjčení nebo udělení státních vyzname
# Ok
# 13
# 85
#  25. května 2018
# Návrhy Poslanecké sněmovny na propůjčení nebo udělení státních vyzname
# Ok
# 13
# 86
#  25. května 2018
# Návrhy Poslanecké sněmovny na propůjčení nebo udělení státních vyzname
# Ok
# 13
# 87
#  25. května 2018
# Návrhy Poslanecké sněmovny na propůjčení nebo udělení státních vyzname
# Ok
# 13
# 88
#  25. května 2018
# Návrhy Poslanecké sněmovny na propůjčení nebo udělení státních vyzname
# Ok
# 13
# 89
#  25. května 2018
# Návrhy Poslanecké sněmovny na propůjčení nebo udělení státních vyzname
# Ok
# 13
# 90
#  25. května 2018
# Návrhy Poslanecké sněmovny na propůjčení nebo udělení státních vyzname
# Ok
# 13
# 91
#  25. května 2018
# Návrhy Poslanecké sněmovny na propůjčení nebo udělení státních vyzname
# Ok
# 13
# 92
#  25. května 2018
# Návrhy Poslanecké sněmovny na propůjčení nebo udělení státních vyzname
# Ok
# 13
# 93
#  25. května 2018
# Návrhy Poslanecké sněmovny na propůjčení nebo udělení státních vyzname
# Ok
# 13
# 94
#  25. května 2018
# Návrhy Poslanecké sněmovny na propůjčení nebo udělení státních vyzname
# Ok
# 13
# 95
#  25. května 2018
# Návrhy Poslanecké sněmovny na propůjčení nebo udělení státních vyzname
# Ok
# 13
# 96
#  25. května 2018
# Návrhy Poslanecké sněmovny na propůjčení nebo udělení státních vyzname
# Ok
# 13
# 97
#  25. května 2018
# Návrhy Poslanecké sněmovny na propůjčení nebo udělení státních vyzname
# Ok
# 13
# 98
#  25. května 2018
# Návrhy Poslanecké sněmovny na propůjčení nebo udělení státních vyzname
# Ok
# 13
# 99
#  25. května 2018
# Návrhy Poslanecké sněmovny na propůjčení nebo udělení státních vyzname
# Ok
# 13
# 100
#  25. května 2018
# Návrhy Poslanecké sněmovny na propůjčení nebo udělení státních vyzname
# Ok
# 13
# 1
#  22. května 2018
# None
# Ok
# 13
# 2
#  22. května 2018
# Pořad schůze
# Ok
# 13
# 3
#  22. května 2018
# Pořad schůze
# Ok
# 13
# 4
#  22. května 2018
# Pořad schůze
# Ok
# 13
# 5
#  22. května 2018
# Pořad schůze
# Ok
# 13
# 6
#  22. května 2018
# Pořad schůze
# Ok
# 13
# 7
#  22. května 2018
# Pořad schůze
# Ok
# 13
# 8
#  22. května 2018
# Pořad schůze
# Ok
# 13
# 9
#  22. května 2018
# Pořad schůze
# Ok
# 13
# 10
#  22. května 2018
# Pořad schůze
# Ok
# 13
# 11
#  22. května 2018
# Pořad schůze
# Ok
# 13
# 12
#  22. května 2018
# Pořad schůze
# Ok
# 13
# 13
#  22. května 2018
# Pořad schůze
# Ok
# 13
# 14
#  22. května 2018
# Pořad schůze
# Ok
# 13
# 15
#  22. května 2018
# Pořad schůze
# Ok
# 13
# 16
#  22. května 2018
# Pořad schůze
# Ok
# 13
# 17
#  22. května 2018
# Pořad schůze
# Ok
# 13
# 18
#  22. května 2018
# Pořad schůze
# Ok
# 13
# 19
#  22. května 2018
# Novela z. o ochranných známkách - EU
# Ok
# 13
# 20
#  22. května 2018
# Novela z. o ochranných známkách - EU
# Ok
# 13
# 161
#  30. května 2018
# N.z. o zálohovaném výživném
# Ok
# 13
# 162
#  31. května 2018
# Pořad schůze
# Ok
# 13
# 163
#  31. května 2018
# Pořad schůze
# Ok
# 13
# 164
#  31. května 2018
# Pořad schůze
# Ok
# 13
# 165
#  31. května 2018
# Pořad schůze
# Ok
# 13
# 166
#  31. května 2018
# Pořad schůze
# Ok
# 13
# 167
#  31. května 2018
# Pořad schůze
# Ok
# 13
# 168
#  31. května 2018
# Pořad schůze
# Ok
# 13
# 169
#  31. května 2018
# Pořad schůze
# Ok
# 13
# 170
#  31. května 2018
# Sml.o stabilitě, koordinaci a správě v hosp. a měnové unii
# Ok
# 13
# 171
#  31. května 2018
# Sml.o stabilitě, koordinaci a správě v hosp. a měnové unii
# Ok
# 13
#
# Cannot open page
# 13
#
# Cannot open page
# 13
# 174
#  1. června 2018
# Pořad schůze
# Ok
# 13
# 175
#  1. června 2018
# Pořad schůze
# Ok
# 13
# 176
#  1. června 2018
# Pořad schůze
# Ok
# 13
# 177
#  1. června 2018
# Pořad schůze
# Ok
# 13
# 178
#  1. června 2018
# Novela z. o Ústavním soudu
# Ok
# 13
# 179
#  1. června 2018
# Novela z. o mezinárodní justiční spolupráci ve věcech trest. - EU
# Ok
# 13
# 180
#  1. června 2018
# Novela z. o mezinárodní justiční spolupráci ve věcech trest. - EU
# Ok
# 13
# 121
#  29. května 2018
# Pořad schůze
# Ok
# 13
# 122
#  29. května 2018
# Pořad schůze
# Ok
# 13
# 123
#  29. května 2018
# Pořad schůze
# Ok
# 13
# 124
#  29. května 2018
# Pořad schůze
# Ok
# 13
# 125
#  29. května 2018
# Novela z. o podmínkách podnikání v oblasti cestovního ruchu - EU
# Ok
# 13
# 126
#  29. května 2018
# Novela z. o střetu zájmů
# Ok
# 13
# 127
#  29. května 2018
# Novela z. o střetu zájmů
# Ok
# 13
# 128
#  29. května 2018
# Novela z. - vodní zákon - EU
# Ok
# 13
# 129
#  29. května 2018
# Novela z.o ochraně zdr.před škodlivými účinky návyk.látek
# Ok
# 13
# 130
#  29. května 2018
# Novela z.o ochraně zdr.před škodlivými účinky návyk.látek
# Ok
# 13
# 131
#  29. května 2018
# Novela z.o ochraně zdr.před škodlivými účinky návyk.látek
# Ok
# 13
# 132
#  29. května 2018
# Vl.n.z. o přístupnosti internetových stránek a mob. aplikací - EU
# Ok
# 13
# 133
#  29. května 2018
# Vl.n.z. o znalcích, znaleckých kanc. a znaleckých ústavech - EU
# Ok
# 13
# 134
#  29. května 2018
# Vl.n.z. o znalcích, znaleckých kanc. a znaleckých ústavech - EU
# Ok
# 13
# 135
#  29. května 2018
# Vl.n.z. o soudních tlumočnících a soudních překladatelích - EU
# Ok
# 13
# 136
#  29. května 2018
# Vl.n.z. o soudních tlumočnících a soudních překladatelích - EU
# Ok
# 13
# 137
#  29. května 2018
# Vl.n.z. o soudních tlumočnících a soudních překladatelích - EU
# Ok
# 13
# 138
#  29. května 2018
# Vl.n.z.o změně zák.v souv.s přij. z. o znalcích a soud.tlum. - EU
# Ok
# 13
# 139
#  29. května 2018
# Vl.n.z.o změně zák.v souv.s přij. z. o znalcích a soud.tlum. - EU
# Ok
# 13
# 140
#  29. května 2018
# Vl.n.z.o změně zák.v souv.s přij. z. o znalcích a soud.tlum. - EU
# Ok
# 13
# 101
#  25. května 2018
# Návrhy Poslanecké sněmovny na propůjčení nebo udělení státních vyzname
# Ok
# 13
# 102
#  25. května 2018
# Návrhy Poslanecké sněmovny na propůjčení nebo udělení státních vyzname
# Ok
# 13
# 103
#  25. května 2018
# Návrhy Poslanecké sněmovny na propůjčení nebo udělení státních vyzname
# Ok
# 13
# 104
#  25. května 2018
# Návrhy Poslanecké sněmovny na propůjčení nebo udělení státních vyzname
# Ok
# 13
# 105
#  25. května 2018
# Návrhy Poslanecké sněmovny na propůjčení nebo udělení státních vyzname
# Ok
# 13
# 106
#  25. května 2018
# Návrhy Poslanecké sněmovny na propůjčení nebo udělení státních vyzname
# Ok
# 13
# 107
#  25. května 2018
# Návrhy Poslanecké sněmovny na propůjčení nebo udělení státních vyzname
# Ok
# 13
# 108
#  25. května 2018
# Návrhy Poslanecké sněmovny na propůjčení nebo udělení státních vyzname
# Ok
# 13
# 109
#  25. května 2018
# Návrhy Poslanecké sněmovny na propůjčení nebo udělení státních vyzname
# Ok
# 13
# 110
#  25. května 2018
# Návrhy Poslanecké sněmovny na propůjčení nebo udělení státních vyzname
# Ok
# 13
# 111
#  25. května 2018
# N.z. o celostátním referendu
# Ok
# 13
# 112
#  25. května 2018
# N.z. o celostátním referendu
# Ok
# 13
# 113
#  25. května 2018
# N.z. o celostátním referendu
# Ok
# 13
# 114
#  25. května 2018
# Novela z. - trestní řád
# Ok
# 13
# 115
#  25. května 2018
# Vl.n.z. o znalcích, znaleckých kanc. a znaleckých ústavech - EU
# Ok
# 13
# 116
#  25. května 2018
# Vl.n.z. o znalcích, znaleckých kanc. a znaleckých ústavech - EU
# Ok
# 13
# 117
#  25. května 2018
# Vl.n.z. o znalcích, znaleckých kanc. a znaleckých ústavech - EU
# Ok
# 13
# 118
#  29. května 2018
# Pořad schůze
# Ok
# 13
# 119
#  29. května 2018
# Pořad schůze
# Ok
# 13
# 120
#  29. května 2018
# Pořad schůze
# Ok
# 13
# 141
#  29. května 2018
# Vl.n.z.o změně zák.v souv.s přij. z. o znalcích a soud.tlum. - EU
# Ok
# 13
# 142
#  30. května 2018
# Vl.n.z.o poskyt.st.záruky ČR na zajištění půjčky ČNB pro MMF
# Ok
# 13
# 143
#  30. května 2018
# Novela z. o ozdravných postupech - EU
# Ok
# 13
# 144
#  30. května 2018
# Novela z. - zákoník práce
# Ok
# 13
# 145
#  30. května 2018
# Novela z. - zákoník práce
# Ok
# 13
# 146
#  30. května 2018
# Novela z. - zákoník práce
# Ok
# 13
# 147
#  30. května 2018
# Novela z. - zákoník práce
# Ok
# 13
# 148
#  30. května 2018
# Novela z. - zákoník práce
# Ok
# 13
# 149
#  30. května 2018
# Novela z. - školský zákon
# Ok
# 13
# 150
#  30. května 2018
# Novela z. - školský zákon
# Ok
# 13
# 151
#  30. května 2018
# Novela z. - školský zákon
# Ok
# 13
# 152
#  30. května 2018
# Novela z. - stavební zákon
# Ok
# 13
# 153
#  30. května 2018
# Novela z. o regulaci reklamy
# Ok
# 13
# 154
#  30. května 2018
# Novela z. o nelékařských zdravotnických povoláních
# Ok
# 13
# 155
#  30. května 2018
# N.z. o náhradním výživném
# Ok
# 13
# 156
#  30. května 2018
# N.z. o náhradním výživném
# Ok
# 13
# 157
#  30. května 2018
# N.z. o náhradním výživném
# Ok
# 13
# 158
#  30. května 2018
# N.z. o náhradním výživném
# Ok
# 13
# 159
#  30. května 2018
# N.z. o zálohovaném výživném
# Ok
# 13
# 160
#  30. května 2018
# N.z. o zálohovaném výživném
# Ok
# 13
# 61
#  23. května 2018
# Novela z. o státní službě
# Ok
# 13
# 62
#  23. května 2018
# Novela z. o státní službě
# Ok
# 13
# 63
#  23. května 2018
# Novela z. o státní službě
# Ok
# 13
# 64
#  23. května 2018
# Novela z. o státní službě
# Ok
# 13
# 65
#  23. května 2018
# Novela z. o státní službě
# Ok
# 13
# 66
#  23. května 2018
# Novela z. o státní službě
# Ok
# 13
# 67
#  23. května 2018
# Novela z. o státní službě
# Ok
# 13
# 68
#  24. května 2018
# Pořad schůze
# Ok
# 13
# 69
#  24. května 2018
# Pořad schůze
# Ok
# 13
# 70
#  24. května 2018
# Pořad schůze
# Ok
# 13
# 71
#  24. května 2018
# Projednání důsledků Marakéšského protokolu
# Ok
# 13
# 72
#  24. května 2018
# Projednání důsledků Marrákešského protokolu
# Ok
# 13
# 73
#  24. května 2018
# Projednání důsledků Marrákešského protokolu
# Ok
# 13
# 74
#  24. května 2018
# Projednání důsledků Marrákešského protokolu
# Ok
# 13
# 75
#  25. května 2018
# Pořad schůze
# Ok
# 13
# 76
# ...
# Ok
# 27
# 200
#  8. března 2019
# Novela z. o podpoře sportu
# Ok
# 27
# 221
#  13. března 2019
# Pořad schůze
# Ok
# 27
# 222
#  13. března 2019
# Novela z. o pobytu cizinců na území ČR - EU
# Ok
# 27
# 223
#  13. března 2019
# Novela z. o pobytu cizinců na území ČR - EU
# Ok
# 27
# 224
#  13. března 2019
# Novela z. o pobytu cizinců na území ČR - EU
# Ok
# 27
# 225
#  13. března 2019
# Novela z. o pobytu cizinců na území ČR - EU
# Ok
# 27
# 226
#  13. března 2019
# Novela z. o pobytu cizinců na území ČR - EU
# Ok
# 27
# 227
#  13. března 2019
# Novela z. o pobytu cizinců na území ČR - EU
# Ok
# 27
# 228
#  13. března 2019
# Novela z. o pobytu cizinců na území ČR - EU
# Ok
# 27
# 229
#  13. března 2019
# Novela z. o pobytu cizinců na území ČR - EU
# Ok
# 27
# 230
#  13. března 2019
# Novela z. o pobytu cizinců na území ČR - EU
# Ok
# 27
# 231
#  13. března 2019
# Novela z. o pobytu cizinců na území ČR - EU
# Ok
# 27
# 232
#  13. března 2019
# Novela z. o pobytu cizinců na území ČR - EU
# Ok
# 27
# 233
#  13. března 2019
# Novela z. o pobytu cizinců na území ČR - EU
# Ok
# 27
# 234
#  13. března 2019
# Novela z. o pobytu cizinců na území ČR - EU
# Ok
# 27
# 235
#  13. března 2019
# Novela z. o pobytu cizinců na území ČR - EU
# Ok
# 27
# 236
#  13. března 2019
# Novela z. o pobytu cizinců na území ČR - EU
# Ok
# 27
# 237
#  13. března 2019
# Novela z. o pobytu cizinců na území ČR - EU
# Ok
# 27
# 238
#  13. března 2019
# Novela z. o pobytu cizinců na území ČR - EU
# Ok
# 27
# 239
#  13. března 2019
# Novela z. o pobytu cizinců na území ČR - EU
# Ok
# 27
# 240
#  13. března 2019
# Novela z. o pobytu cizinců na území ČR - EU
# Ok
# 27
# 121
#  7. března 2019
# Dodat. prot. k Úmluvě o lidských právech a biomedicíně
# Ok
# 27
# 122
#  7. března 2019
# Sml. mezi ČR a Ghanou o zamezení dvojímu zdanění
# Ok
# 27
# 123
#  7. března 2019
# Změny příloh A a C Stockholmské úmluvy
# Ok
# 27
# 124
#  7. března 2019
# Změna a ukonč.Doh.mezi ČR a Polskem o podp.inv.
# Ok
# 27
# 125
#  7. března 2019
# Změna Doh.mezi ČR a Lotyšskem o podp.a vzáj.ochr.inv.
# Ok
# 27
# 126
#  7. března 2019
# Návrh doporučení Rady o přístupu prac.a OSVČ k soc.ochraně
# Ok
# 27
# 127
#  7. března 2019
# Doporučení MOP č. 205 o zam.a důst.práci pro mír a odolnost
# Ok
# 27
# 128
#  7. března 2019
# Doh.o ochraně investic mezi EU a Singapurem
# Ok
# 27
# 129
#  7. března 2019
# Dohoda o partnerství a spolupráci mezi EU a Singapurem
# Ok
# 27
# 130
#  7. března 2019
# Dohoda o partnerství a spolupráci mezi EU a Singapurem
# Ok
# 27
# 131
#  7. března 2019
# Sml.mezi ČR a SR o aktualizaci hraničního dokum.díla
# Ok
# 27
# 132
#  7. března 2019
# Sml.mezi ČR a SR o aktualizaci hraničního dokum.díla
# Ok
# 27
# 133
#  8. března 2019
# Pořad schůze
# Ok
# 27
# 134
#  8. března 2019
# Pořad schůze
# Ok
# 27
# 135
#  8. března 2019
# Pořad schůze
# Ok
# 27
# 136
#  8. března 2019
# Pořad schůze
# Ok
# 27
# 137
#  8. března 2019
# Pořad schůze
# Ok
# 27
# 138
#  8. března 2019
# Pořad schůze
# Ok
# 27
#
# Cannot open page
# 27
#
# Cannot open page
# 27
# 281
#  13. března 2019
# Novela z. o krmivech - EU
# Ok
# 27
# 282
#  14. března 2019
# Pořad schůze
# Ok
# 27
# 283
#  14. března 2019
# Pořad schůze
# Ok
# 27
# 284
#  15. března 2019
# Pořad schůze
# Ok
# 27
# 285
#  15. března 2019
# Pořad schůze
# Ok
# 27
# 286
#  15. března 2019
# Pořad schůze
# Ok
# 27
# 287
#  15. března 2019
# Pořad schůze
# Ok
# 27
# 288
#  15. března 2019
# Pořad schůze
# Ok
# 27
# 289
#  15. března 2019
# Návrh nařízení Rady v souvislosti s vystoupením VB z EU
# Ok
# 27
# 290
#  15. března 2019
# Novela z. o krmivech - EU
# Ok
# 27
# 291
#  15. března 2019
# Novela z. o lesích (lesní zákon)
# Ok
# 27
# 292
#  15. března 2019
# Novela z. o lesích (lesní zákon)
# Ok
# 27
# 293
#  15. března 2019
# Novela z. o lesích (lesní zákon)
# Ok
# 27
# 294
#  15. března 2019
# Novela z. o lesích (lesní zákon)
# Ok
# 27
# 295
#  15. března 2019
# Novela z. o lesích (lesní zákon)
# Ok
# 27
# 296
#  15. března 2019
# Novela z. o pojistném na sociální zabezpečení
# Ok
# 27
# 297
#  26. března 2019
# Pořad schůze
# Ok
# 27
# 298
#  26. března 2019
# Pořad schůze
# Ok
# 27
# 299
#  26. března 2019
# Pořad schůze
# Ok
# 27
# 300
#  26. března 2019
# Návrh na změnu usnesení PS č. 58 ze dne 12. prosince 2017
# Ok
# 27
# 21
#  5. března 2019
# Pořad schůze
# Ok
# 27
# 22
#  5. března 2019
# Pořad schůze
# Ok
# 27
# 23
#  5. března 2019
# Pořad schůze
# Ok
# 27
# 24
#  5. března 2019
# Pořad schůze
# Ok
# 27
# 25
#  5. března 2019
# Pořad schůze
# Ok
# 27
# 26
#  5. března 2019
# Pořad schůze
# Ok
# 27
# 27
#  5. března 2019
# Pořad schůze
# Ok
# 27
# 28
#  5. března 2019
# Pořad schůze
# Ok
# 27
# 29
#  5. března 2019
# Pořad schůze
# Ok
# 27
# 30
#  5. března 2019
# Novela z. o podpoře regionálního rozvoje
# Ok
# 27
# 31
#  5. března 2019
# Novela z. o ochraně spotřebitele - EU
# Ok
# 27
# 32
#  5. března 2019
# Novela z. o ochraně spotřebitele - EU
# Ok
# 27
# 33
#  5. března 2019
# Novela z. o služeb. poměru příslušníků bezpečnostních sborů
# Ok
# 27
# 34
#  5. března 2019
# Novela z. o služeb. poměru příslušníků bezpečnostních sborů
# Ok
# 27
# 35
#  5. března 2019
# Novela z. o služeb. poměru příslušníků bezpečnostních sborů
# Ok
# 27
# 36
#  5. března 2019
# Novela z. o služeb. poměru příslušníků bezpečnostních sborů
# Ok
# 27
# 37
#  5. března 2019
# Novela z. o služeb. poměru příslušníků bezpečnostních sborů
# Ok
# 27
# 38
#  5. března 2019
# Novela z. o hospodaření energií - EU
# Ok
# 27
# 39
#  5. března 2019
# Novela z. o hospodaření energií - EU
# Ok
# 27
# 40
#  5. března 2019
# Novela z. o hospodaření energií - EU
# Ok
# 27
# 241
#  13. března 2019
# Novela z. o pobytu cizinců na území ČR - EU
# Ok
# 27
# 242
#  13. března 2019
# Novela z. o pobytu cizinců na území ČR - EU
# Ok
# 27
# 243
#  13. března 2019
# Novela z. o pobytu cizinců na území ČR - EU
# Ok
# 27
# 244
#  13. března 2019
# Novela z. o pobytu cizinců na území ČR - EU
# Ok
# 27
# 245
#  13. března 2019
# Novela z. o pobytu cizinců na území ČR - EU
# Ok
# 27
# 246
#  13. března 2019
# Novela z. o pobytu cizinců na území ČR - EU
# Ok
# 27
# 247
#  13. března 2019
# Novela z. o pobytu cizinců na území ČR - EU
# Ok
# 27
# 248
#  13. března 2019
# Novela z. o podpoře sportu
# Ok
# 27
# 249
#  13. března 2019
# Novela z. o podpoře sportu
# Ok
# 27
# 250
#  13. března 2019
# Novela z. o podpoře sportu
# Ok
# 27
# 251
#  13. března 2019
# Novela z. o podpoře sportu
# Ok
# 27
# 252
#  13. března 2019
# Novela z. o podpoře sportu
# Ok
# 27
# 253
#  13. března 2019
# Novela z. o podpoře sportu
# Ok
# 27
# 254
#  13. března 2019
# Novela z. o podpoře sportu
# Ok
# 27
# 255
#  13. března 2019
# Novela z. o obcích
# Ok
# 27
# 256
#  13. března 2019
# Novela z. o obcích
# Ok
# 27
# 257
#  13. března 2019
# Novela z. o obcích
# Ok
# 27
# 258
#  13. března 2019
# Novela z. o obcích
# Ok
# 27
# 259
#  13. března 2019
# Novela z. o obcích
# Ok
# 27
# 260
#  13. března 2019
# Novela z. o obcích
# Ok
# 27
# 301
#  26. března 2019
# Novela z. o zemědělství
# Ok
# 27
# 302
#  26. března 2019
# Novela z. o pozemních komunikacích
# Ok
# 27
# 303
#  26. března 2019
# Sloučená rozprava k bodům 37 a 38
# Ok
# 27
#
# Cannot open page
# 27
# 305
#  26. března 2019
# Kontrola plnění usnesení PS č. 66
# Ok
# 27
# 306
#  26. března 2019
# Kontrola plnění usnesení PS č. 66
# Ok
# 27
# 307
#  26. března 2019
# Kontrola plnění usnesení PS č. 66
# Ok
# 27
# 308
#  26. března 2019
# Kontrola plnění usnesení PS č. 66
# Ok
# 27
# 309
#  26. března 2019
# Kontrola plnění usnesení PS č. 66
# Ok
# 27
# 310
#  26. března 2019
# Kontrola plnění usnesení PS č. 66
# Ok
# 27
# 311
#  26. března 2019
# Kontrola plnění usnesení PS č. 66
# Ok
# 27
# 312
#  27. března 2019
# None
# Ok
# 27
# 313
#  27. března 2019
# None
# Ok
# 27
# 314
#  27. března 2019
# Kontrola plnění usnesení PS č. 66
# Ok
# 27
# 315
#  27. března 2019
# Kontrola plnění usnesení PS č. 66
# Ok
# 27
# 316
#  27. března 2019
# Kontrola plnění usnesení PS č. 66
# Ok
# 27
# 317
#  27. března 2019
# Kontrola plnění usnesení PS č. 66
# Ok
# 27
# 318
#  27. března 2019
# Pořad schůze
# Ok
# 27
# 319
#  27. března 2019
# Návrh na jmenování členů KR GA ČR
# Ok
# 27
# 320
#  27. března 2019
# Návrh na jmenování členů KR TA ČR
# Ok
# 27
# 261
#  13. března 2019
# Novela z. o obcích
# Ok
# 27
# 262
#  13. března 2019
# Novela z. o obcích
# Ok
# 27
# 263
#  13. března 2019
# Novela z. o obcích
# Ok
# 27
# 264
#  13. března 2019
# N. z. o činnosti inst. zaměstnaneckého penzijního pojištění - EU
# Ok
# 27
# 265
#  13. března 2019
# Návrh na změny ve složení orgánů Poslanecké sněmovny
# Ok
# 27
# 266
#  13. března 2019
# Návrh na změny ve složení orgánů Poslanecké sněmovny
# Ok
# 27
# 267
#  13. března 2019
# Návrh na volbu člena DR SFDI
# Ok
# 27
# 268
#  13. března 2019
# Návrh na jmenování členů RRTV
# Ok
# 27
# 269
#  13. března 2019
# Návrh na volbu kandidátů na člena Rady ÚSTR
# Ok
# 27
# 270
#  13. března 2019
# Návrh na volbu člena Dozorčí rady Vinařského fondu
# Ok
# 27
# 271
#  13. března 2019
# Návrh na volbu členů RČRo
# Ok
# 27
# 272
#  13. března 2019
# Návrh na volbu zástupce Veřejného ochránce práv
# Ok
# 27
# 273
#  13. března 2019
# Vl.n.z. o územně správním členění státu
# Ok
# 27
# 274
#  13. března 2019
# Žádost o vyslovení souhlasu PS k trestnímu stíhání M. Roznera
# Ok
# 27
#
# Cannot open page
# 27
# 276
#  13. března 2019
# Novela z. - živnostenský zákon
# Ok
# 27
# 277
#  13. března 2019
# Novela z. - živnostenský zákon
# Ok
# 27
# 278
#  13. března 2019
# Novela z. - živnostenský zákon
# Ok
# 27
# 279
#  13. března 2019
# Novela z. - živnostenský zákon
# Ok
# 27
# 280
#  13. března 2019
# Novela z. o Státním pozemkovém úřadu
# Ok
# 27
# 101
#  6. března 2019
# Připomenutí významu a zásluh Aloise Rašína
# Ok
# 27
# 102
#  6. března 2019
# Novela z. o lesích (lesní zákon)
# Ok
# 27
# 103
#  6. března 2019
# Novela z. o lesích (lesní zákon)
# Ok
# 27
# 104
#  6. března 2019
# Návrh usnesení PS ke sněmovnímu tisku 382
# Ok
# 27
# 105
#  6. března 2019
# Návrh usnesení PS ke sněmovnímu tisku 382
# Ok
# 27
# 106
#  6. března 2019
# Návrh usnesení PS ke sněmovnímu tisku 382
# Ok
# 27
# 107
#  6. března 2019
# Novela z. o provozu na pozemních komunikacích
# Ok
# 27
# 108
#  6. března 2019
# Novela z. - daňový řád
# Ok
# 27
# 109
#  6. března 2019
# Novela z. o provozu na pozemních komunikacích
# Ok
# 27
# 110
#  6. března 2019
# Novela z. o provozu na pozemních komunikacích
# Ok
# 27
# 111
#  6. března 2019
# Novela z. o obchodních korporacích - EU
# Ok
# 27
# 112
#  6. března 2019
# Novela z. o obchodních korporacích - EU
# Ok
# 27
# 113
#  6. března 2019
# Novela z. o obchodních korporacích - EU
# Ok
# 27
# 114
#  6. března 2019
# Novela z. o obchodních korporacích - EU
# Ok
# 27
# 115
#  6. března 2019
# Novela z. o obchodních korporacích - EU
# Ok
# 27
# 116
#  6. března 2019
# Novela z. o pohonných hmotách
# Ok
# 27
# 117
#  7. března 2019
# Písemná interpelace J. Michálka na A. Babiše ve věci neprůhledného hos
# Ok
# 27
# 118
#  7. března 2019
# Písemná interpelace V. Munzara na A. Schillerovou ve věci postupu FS Č
# Ok
# 27
# 119
#  7. března 2019
# Písemná interpelace V. Munzara na A. Schillerovou ve věci odměňování ú
# Ok
# 27
# 120
#  7. března 2019
# Rámcová dohoda mezi EU a Austrálií
# Ok
# 27
# 1
#  5. března 2019
# None
# Ok
# 27
# 2
#  5. března 2019
# Pořad schůze
# Ok
# 27
# 3
#  5. března 2019
# Pořad schůze
# Ok
# 27
# 4
#  5. března 2019
# Pořad schůze
# Ok
# 27
# 5
#  5. března 2019
# Pořad schůze
# Ok
# 27
# 6
#  5. března 2019
# Pořad schůze
# Ok
# 27
# 7
#  5. března 2019
# Pořad schůze
# Ok
# 27
# 8
#  5. března 2019
# Pořad schůze
# Ok
# 27
# 9
#  5. března 2019
# Pořad schůze
# Ok
# 27
# 10
#  5. března 2019
# Pořad schůze
# Ok
# 27
# 11
#  5. března 2019
# Pořad schůze
# Ok
# 27
# 12
#  5. března 2019
# Pořad schůze
# Ok
# 27
# 13
#  5. března 2019
# Pořad schůze
# Ok
# 27
# 14
#  5. března 2019
# Pořad schůze
# Ok
# 27
# 15
#  5. března 2019
# Pořad schůze
# Ok
# 27
# 16
#  5. března 2019
# Pořad schůze
# Ok
# 27
# 17
#  5. března 2019
# Pořad schůze
# Ok
# 27
# 18
#  5. března 2019
# Pořad schůze
# Ok
# 27
# 19
#  5. března 2019
# Pořad schůze
# Ok
# 27
# 20
#  5. března 2019
# Pořad schůze
# Ok
# 27
# 321
#  27. března 2019
# Postoj vlády k problémům s financováním sociálních služeb
# Ok
# 27
# 322
#  27. března 2019
# Postoj vlády k problémům s financováním sociálních služeb
# Ok
# 27
# 323
#  27. března 2019
# Postoj vlády k problémům s financováním sociálních služeb
# Ok
# 27
# 324
#  27. března 2019
# Postoj vlády k problémům s financováním sociálních služeb
# Ok
# 27
# 325
#  27. března 2019
# Postoj vlády k problémům s financováním sociálních služeb
# Ok
# 27
# 326
#  27. března 2019
# Postoj vlády k problémům s financováním sociálních služeb
# Ok
# 27
# 327
#  27. března 2019
# Postoj vlády k problémům s financováním sociálních služeb
# Ok
# 27
# 328
#  27. března 2019
# Postoj vlády k problémům s financováním sociálních služeb
# Ok
# 27
# 329
#  27. března 2019
# Postoj vlády k problémům s financováním sociálních služeb
# Ok
# 27
# 330
#  27. března 2019
# Informace vlády o výběrovém řízení na mýtný systém
# Ok
# 27
# 331
#  27. března 2019
# Informace vlády o výběrovém řízení na mýtný systém
# Ok
# 27
# 332
#  27. března 2019
# Informace vlády o výběrovém řízení na mýtný systém
# Ok
# 27
# 333
#  27. března 2019
# Informace vlády o výběrovém řízení na mýtný systém
# Ok
# 27
# 334
#  27. března 2019
# Informace vlády o výběrovém řízení na mýtný systém
# Ok
# 28
# 101
#  23. dubna 2019
# Novela z. o finanční kontrole - EU
# Ok
# 28
# 102
#  23. dubna 2019
# Novela z. - energetický zákon
# Ok
# 28
# 103
#  23. dubna 2019
# Novela z. o provozu na pozemních komunikacích
# Ok
# 28
# 104
#  24. dubna 2019
# Novela z. o elektronických komunikacích
# Ok
# 28
# 105
#  24. dubna 2019
# Novela z. o elektronických komunikacích
# Ok
# 28
# 106
#  24. dubna 2019
# Vl.n.z. o realitním zprostředkování - EU
# Ok
# 28
# 107
#  24. dubna 2019
# Vl.n.z. o realitním zprostředkování - EU
# Ok
# 28
# 108
#  24. dubna 2019
# Vl.n.z. o realitním zprostředkování - EU
# Ok
# 28
# 109
#  24. dubna 2019
# Vl.n.z. o realitním zprostředkování - EU
# Ok
# 28
# 110
#  24. dubna 2019
# Novela z. o státním občanství ČR
# Ok
# 28
# 111
#  24. dubna 2019
# Vl.n.z. - v oblasti regulace podnikání na finančním trhu - EU
# Ok
# 28
# 112
#  24. dubna 2019
# Novela z. - občanský zákoník
# Ok
# 28
# 113
#  24. dubna 2019
# Novela z. o Státním fondu rozvoje bydlení
# Ok
# 28
# 114
#  24. dubna 2019
# Novela z. o Státním fondu rozvoje bydlení
# Ok
# 28
# 115
#  24. dubna 2019
# Novela z. o Státním fondu rozvoje bydlení
# Ok
# 28
# 116
#  24. dubna 2019
# Novela z. - veterinární zákon - EU
# Ok
# 28
# 117
#  24. dubna 2019
# Novela z. - veterinární zákon - EU
# Ok
# 28
# 118
#  24. dubna 2019
# Novela z. o rostlinolékařské péči - EU
# Ok
# 28
# 119
#  24. dubna 2019
# Novela z. o rostlinolékařské péči - EU
# Ok
# 28
# 120
#  24. dubna 2019
# Vl.n.z. o náhradě újmy způs.povinným očkováním
# Ok
# 28
# 1
#  16. dubna 2019
# None
# Ok
# 28
# 2
#  16. dubna 2019
# Pořad schůze
# Ok
# 28
# 3
#  16. dubna 2019
# Pořad schůze
# Ok
# 28
# 4
#  16. dubna 2019
# Pořad schůze
# Ok
# 28
# 5
#  16. dubna 2019
# Pořad schůze
# Ok
# 28
# 6
#  16. dubna 2019
# Pořad schůze
# Ok
# 28
# 7
#  16. dubna 2019
# Pořad schůze
# Ok
# 28
#
# Cannot open page
# 28
# 9
#  16. dubna 2019
# Pořad schůze
# Ok
# 28
# 10
#  16. dubna 2019
# Pořad schůze
# Ok
# 28
# 11
#  16. dubna 2019
# Pořad schůze
# Ok
# 28
# 12
#  16. dubna 2019
# Pořad schůze
# Ok
# 28
# 13
#  16. dubna 2019
# Pořad schůze
# Ok
# 28
# 14
#  16. dubna 2019
# Pořad schůze
# Ok
# 28
# 15
#  16. dubna 2019
# Pořad schůze
# Ok
# 28
# 16
#  16. dubna 2019
# Pořad schůze
# Ok
# 28
# 17
#  16. dubna 2019
# Pořad schůze
# Ok
# 28
# 18
#  16. dubna 2019
# Pořad schůze
# Ok
# 28
# 19
#  16. dubna 2019
# Pořad schůze
# Ok
# 28
# 20
#  16. dubna 2019
# Pořad schůze
# Ok
# 28
# 61
#  17. dubna 2019
# Návrh na změny ve složení orgánů Poslanecké sněmovny
# Ok
# 28
# 62
#  17. dubna 2019
# Návrh na změny ve složení orgánů Poslanecké sněmovny
# Ok
# 28
# 63
#  17. dubna 2019
# Návrh na změny ve složení orgánů Poslanecké sněmovny
# Ok
# 28
# 64
#  17. dubna 2019
# Návrh na změny ve složení orgánů Poslanecké sněmovny
# Ok
# 28
# 65
#  17. dubna 2019
# Návrh na změny ve složení orgánů Poslanecké sněmovny
# Ok
# 28
# 66
#  17. dubna 2019
# Vl.n.z. o zamezení dvojímu zdanění ve vztahu k Tchaj-wanu
# Ok
# 28
# 67
#  17. dubna 2019
# Vl.n.z. o zamezení dvojímu zdanění ve vztahu k Tchaj-wanu
# Ok
# 28
# 68
#  17. dubna 2019
# Vl.n.z. o zamezení dvojímu zdanění ve vztahu k Tchaj-wanu
# Ok
# 28
# 69
#  17. dubna 2019
# Vl.n.z. o zamezení dvojímu zdanění ve vztahu k Tchaj-wanu
# Ok
# 28
# 70
#  18. dubna 2019
# Písemná interpelace V. Kovářové na A. Babiše ve věci ceny energií
# Ok
# 28
# 71
#  18. dubna 2019
# Písemná interpelace Z. Stanjury na J. Maláčovou ve věci dalších kroků
# Ok
# 28
# 72
#  18. dubna 2019
# Pořad schůze
# Ok
# 28
# 73
#  18. dubna 2019
# Pořad schůze
# Ok
# 28
# 74
#  18. dubna 2019
# Návrh časového harmonogramu projednávání vládního návrhu státního závě
# Ok
# 28
# 75
#  18. dubna 2019
# Návrh změny rozpočtu SFRB na rok 2019
# Ok
# 28
# 76
#  18. dubna 2019
# Zpr. o činnosti kontrolní rady GA ČR říjen 2017 - září 2018
# Ok
# 28
# 77
#  18. dubna 2019
# Zpr. o činnosti kontrolní rady GA ČR říjen 2017 - září 2018
# Ok
# 28
# 78
#  18. dubna 2019
# Prot.prodlužující Dohodu mezi ČR a USA o vědec. spolup.
# Ok
# 28
# 79
#  18. dubna 2019
# Doh. mezi ČR a vládou Mongolska o leteckých službách
# Ok
# 28
# 80
#  18. dubna 2019
# Doh.o partnerství mezi EU a ES pro atom.energ. a Arménií
# Ok
# 28
# 161
#  10. května 2019
# Novela z. o pojistném na sociální zabezpečení
# Ok
# 28
# 162
#  10. května 2019
# Novela z. o pojistném na sociální zabezpečení
# Ok
# 28
# 163
#  10. května 2019
# Novela z. o pojistném na sociální zabezpečení
# Ok
# 28
# 164
#  10. května 2019
# Novela z. o pojistném na sociální zabezpečení
# Ok
# 28
# 165
#  10. května 2019
# Novela z. o pojistném na sociální zabezpečení
# Ok
# 28
# 166
#  10. května 2019
# Novela z. o pojistném na sociální zabezpečení
# Ok
# 28
# 167
#  10. května 2019
# Novela z. o evidenci tržeb - EU
# Ok
# 28
# 21
#  16. dubna 2019
# Pořad schůze
# Ok
# 28
# 22
#  16. dubna 2019
# Pořad schůze
# Ok
# 28
# 23
#  16. dubna 2019
# Pořad schůze
# Ok
# 28
# 24
#  16. dubna 2019
# Pořad schůze
# Ok
# 28
# 25
#  16. dubna 2019
# Pořad schůze
# Ok
# 28
# 26
#  16. dubna 2019
# Pořad schůze
# Ok

# %%
#several times kernel was interrupted during downloading the data, so each time downloading were continued in different file, then all are combined in one file
all_filenames = ['HW1_1.csv', 'HW1_2.csv', 'HW1_3.csv', 'HW1_4.csv']
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
combined_csv.to_csv( "Voting_combined.csv", index=False, encoding='utf-8-sig')

# %%
data = pd.read_csv("Voting_combined.csv")
data
# Out:
#          meeting_no  vote_no            vote_date vote_time  \
# 0                 1        2   20. listopadu 2017     13:53
# 1                 1        2   20. listopadu 2017     13:53
# 2                 1        2   20. listopadu 2017     13:53
# 3                 1        2   20. listopadu 2017     13:53
# 4                 1        2   20. listopadu 2017     13:53
# ...             ...      ...                  ...       ...
# 1424995          62      160       23. října 2020     12:54
# 1424996          62      160       23. října 2020     12:54
# 1424997          62      160       23. října 2020     12:54
# 1424998          62      160       23. října 2020     12:54
# 1424999          62      160       23. října 2020     12:54
#
#                                                   agenda     clubs  \
# 0        Inf. o ustavení volební komise PS a volbě členů      ANO
# 1        Inf. o ustavení volební komise PS a volbě členů      ANO
# 2        Inf. o ustavení volební komise PS a volbě členů      ANO
# 3        Inf. o ustavení volební komise PS a volbě členů      ANO
# 4        Inf. o ustavení volební komise PS a volbě členů      ANO
# ...                                                  ...       ...
# 1424995           Novela z. o opatřeních - soudní řízení  Nezařaz
# 1424996           Novela z. o opatřeních - soudní řízení  Nezařaz
# 1424997           Novela z. o opatřeních - soudní řízení  Nezařaz
# 1424998           Novela z. o opatřeních - soudní řízení  Nezařaz
# 1424999           Novela z. o opatřeních - soudní řízení  Nezařaz
#
#                              deputies     vote
# 0                        VěraAdámková      ano
# 1                         AndrejBabiš      ano
# 2                      AndreaBabišová      ano
# 3                  MargitaBalaštíková      ano
# 4                         JosefBělica      ano
# ...                               ...      ...
# 1424995                 TerezaHyťhová   zdrzel
# 1424996                   VáclavKlaus  omluven
# 1424997   ZuzanaMajerová Zahradníková  omluven
# 1424998                IvanaNevludová  omluven
# 1424999                  LubomírVolný  omluven
#
# [1425000 rows x 8 columns]

# %% [markdown]
# #### Editing (removing some extra data as brackets, etc) and Formatting (changinh the order of columns) the Data  from file:

# %%
data['deputies'] = data['deputies'].str.replace('\(.*?\)' , '')
data['year'] = data['vote_date'].str[-4:]
data['vote_date'] = data['vote_date'].map(lambda x: str(x)[:-4])

cols = list(data.columns.values)
data = data[['meeting_no',
             'vote_no', 
             'vote_date',
             'year',
             'vote_time',            
             'agenda',
             'clubs',
             'deputies',
             'vote' ]]
data
# Out:
#          meeting_no  vote_no        vote_date  year vote_time  \
# 0                 1        2   20. listopadu   2017     13:53
# 1                 1        2   20. listopadu   2017     13:53
# 2                 1        2   20. listopadu   2017     13:53
# 3                 1        2   20. listopadu   2017     13:53
# 4                 1        2   20. listopadu   2017     13:53
# ...             ...      ...              ...   ...       ...
# 1424995          62      160       23. října   2020     12:54
# 1424996          62      160       23. října   2020     12:54
# 1424997          62      160       23. října   2020     12:54
# 1424998          62      160       23. října   2020     12:54
# 1424999          62      160       23. října   2020     12:54
#
#                                                   agenda     clubs  \
# 0        Inf. o ustavení volební komise PS a volbě členů      ANO
# 1        Inf. o ustavení volební komise PS a volbě členů      ANO
# 2        Inf. o ustavení volební komise PS a volbě členů      ANO
# 3        Inf. o ustavení volební komise PS a volbě členů      ANO
# 4        Inf. o ustavení volební komise PS a volbě členů      ANO
# ...                                                  ...       ...
# 1424995           Novela z. o opatřeních - soudní řízení  Nezařaz
# 1424996           Novela z. o opatřeních - soudní řízení  Nezařaz
# 1424997           Novela z. o opatřeních - soudní řízení  Nezařaz
# 1424998           Novela z. o opatřeních - soudní řízení  Nezařaz
# 1424999           Novela z. o opatřeních - soudní řízení  Nezařaz
#
#                              deputies     vote
# 0                        VěraAdámková      ano
# 1                         AndrejBabiš      ano
# 2                      AndreaBabišová      ano
# 3                  MargitaBalaštíková      ano
# 4                         JosefBělica      ano
# ...                               ...      ...
# 1424995                 TerezaHyťhová   zdrzel
# 1424996                   VáclavKlaus  omluven
# 1424997   ZuzanaMajerová Zahradníková  omluven
# 1424998                IvanaNevludová  omluven
# 1424999                  LubomírVolný  omluven
#
# [1425000 rows x 9 columns]

# %% [markdown]
# ### Task#1 Show deputies who changed their clubs.
# Data of these deputies is saved in dataframe to show properly from and to which club they moved

# %%
deps_changed_club =[]
clubs =[]
deputies_clubs = data['deputies'].str.cat(data[['clubs']],sep=",")
uniq = deputies_clubs.unique()
for elem in uniq:
    a = elem.split(',')
    deputy,club = a[0],a[1]
    deps_changed_club.append(deputy)
    clubs.append(club)

def non_unique(x, c): 
    _size = len(x) 
    repeated = []
    klub_from=[]
    klub_to = []
    counter = 0
    for i in range(_size): 
        k = i + 1
        
        for j in range(k, _size): 
            if x[i] == x[j]:
                counter = counter + 1
            if x[i] == x[j] and x[i] not in repeated and counter <= 2: 
                repeated.append(x[i]) 
                klub_from.append(c[i])
                klub_to.append(c[j])
            elif x[i] == x[j]  and counter > 2:
                repeated.append(x[i]) 
                klub_from.append(c[i])
                klub_to.append(c[j])
                counter = 0 
                
    return repeated, klub_from, klub_to 
deps =[]
club_from=[]
club_to=[]
deps,club_from, club_to= non_unique(deps_changed_club, clubs)

print('deps: ', deps)
print('club_from:', club_from)
print('club_to:', club_to)
# Out:
# deps:  [' VáclavKlaus', ' ZuzanaMajerová Zahradníková', ' MarianBojko', ' TerezaHyťhová', ' IvanaNevludová', ' LubomírVolný', ' JaroslavFoldyna', ' JaroslavFoldyna']
# club_from: ['ODS ', 'ODS ', 'SPD ', 'SPD ', 'SPD ', 'SPD ', 'ČSSD ', 'SPD ']
# club_to: ['Nezařaz ', 'Nezařaz ', 'Nezařaz ', 'Nezařaz ', 'Nezařaz ', 'Nezařaz ', 'SPD ', 'Nezařaz ']

# %%
deps_changed_clubs =pd.DataFrame ({  'from':      ['ODS ', 'ODS ', 'SPD ', 'SPD ', 'SPD ', 'SPD ', 'ČSSD ', 'SPD '],
                                     'to':        ['Nezařaz ', 'Nezařaz ', 'Nezařaz ', 'Nezařaz ', 'Nezařaz ', 'Nezařaz ', 'SPD ', 'Nezařaz '],
                                     'deputies':  ['VáclavKlaus','ZuzanaMajerová Zahradníková','MarianBojko','TerezaHyťhová','IvanaNevludová', 'LubomírVolný' , 'JaroslavFoldyna','JaroslavFoldyna']
                                })
deps_changed_clubs
# Out:
#     from        to                     deputies
# 0   ODS   Nezařaz                   VáclavKlaus
# 1   ODS   Nezařaz   ZuzanaMajerová Zahradníková
# 2   SPD   Nezařaz                   MarianBojko
# 3   SPD   Nezařaz                 TerezaHyťhová
# 4   SPD   Nezařaz                IvanaNevludová
# 5   SPD   Nezařaz                  LubomírVolný
# 6  ČSSD       SPD               JaroslavFoldyna
# 7   SPD   Nezařaz               JaroslavFoldyna

# %% [markdown]
# ### Task 2A: Attendance of individual deputies in the votings.
# According to website the number of attendance in voting is equal to summ of votes as ano, ne and zdrzel. Function returns '1' in this cases of votes and by applying this function the result is saved in a new column "attendance_deputies".

# %%
def attendance(row):
    if row == 'ano' or row == 'ne' or row == 'zdrzel':
        return 1
    elif row == 'omluven' or row == 'neprihlasen':
        return 0
    
data.loc[:,("attendance_deputies")] = data.loc[:,("vote")].apply(attendance)
data
# Out:
# /home/nuray/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1745: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
#          meeting_no  vote_no        vote_date  year vote_time  \
# 0                 1        2   20. listopadu   2017     13:53
# 1                 1        2   20. listopadu   2017     13:53
# 2                 1        2   20. listopadu   2017     13:53
# 3                 1        2   20. listopadu   2017     13:53
# 4                 1        2   20. listopadu   2017     13:53
# ...             ...      ...              ...   ...       ...
# 1424995          62      160       23. října   2020     12:54
# 1424996          62      160       23. října   2020     12:54
# 1424997          62      160       23. října   2020     12:54
# 1424998          62      160       23. října   2020     12:54
# 1424999          62      160       23. října   2020     12:54
#
#                                                   agenda     clubs  \
# 0        Inf. o ustavení volební komise PS a volbě členů      ANO
# 1        Inf. o ustavení volební komise PS a volbě členů      ANO
# 2        Inf. o ustavení volební komise PS a volbě členů      ANO
# 3        Inf. o ustavení volební komise PS a volbě členů      ANO
# 4        Inf. o ustavení volební komise PS a volbě členů      ANO
# ...                                                  ...       ...
# 1424995           Novela z. o opatřeních - soudní řízení  Nezařaz
# 1424996           Novela z. o opatřeních - soudní řízení  Nezařaz
# 1424997           Novela z. o opatřeních - soudní řízení  Nezařaz
# 1424998           Novela z. o opatřeních - soudní řízení  Nezařaz
# 1424999           Novela z. o opatřeních - soudní řízení  Nezařaz
#
#                              deputies     vote  attendance_deputies  \
# 0                        VěraAdámková      ano                    1
# 1                         AndrejBabiš      ano                    1
# 2                      AndreaBabišová      ano                    1
# 3                  MargitaBalaštíková      ano                    1
# 4                         JosefBělica      ano                    1
# ...                               ...      ...                  ...
# 1424995                 TerezaHyťhová   zdrzel                    1
# 1424996                   VáclavKlaus  omluven                    0
# 1424997   ZuzanaMajerová Zahradníková  omluven                    0
# 1424998                IvanaNevludová  omluven                    0
# 1424999                  LubomírVolný  omluven                    0
#
#          vote_result  clubsVote_resInt
# 0                 75                75
# 1                 75                75
# 2                 75                75
# 3                 75                75
# 4                 75                75
# ...              ...               ...
# 1424995            1                 4
# 1424996            4                 4
# 1424997            4                 4
# 1424998            4                 4
# 1424999            4                 4
#
# [1425000 rows x 12 columns]

# %%
#calculating of all vote events in each Meeting, in each Year, and overall (6953) number of vote events from 2017 untill 2020 Ocotber
total = data.groupby(['year', 'meeting_no', 'vote_date'])["vote_no"].nunique().rename("vote_number_total").reset_index()
total_voteEvents_perMeeting = total.groupby(['year', 'meeting_no'])["vote_number_total"].sum()
total_voteEvents_perYear = total.groupby(['year'])["vote_number_total"].sum()
total_voteEvents_perYear
total_voteEvents = total["vote_number_total"].sum()
total_voteEvents
# Out:
# 6953

# %%
# Attendance of deputies in voting.Overall 214 deputies, their attendance is counted by groupping deps and column "deputy_attendance". 
#after sorting we can see that min number of attendance =14, max = 7099 
deputies_attendance_total = data.groupby(['deputies'])["attendance_deputies"].sum().rename("deputy_attendance").reset_index()
deps_attendance_1 = deputies_attendance_total[:50]
deps_attendance_2 = deputies_attendance_total[50:102]
deps_attendance_3 = deputies_attendance_total[102:150]
deps_attendance_4 = deputies_attendance_total[150:]
sorted_deps_attendance_total = deputies_attendance_total.sort_values(by="deputy_attendance")
sorted_deps_attendance_total
# Out:
#                         deputies  deputy_attendance
# 70    JaroslavaPokorná Jermanová                 14
# 74                   JiříHlavatý                 15
# 120                   MartinPůta                 15
# 69               JaroslavVymazal                157
# 10               BohuslavSobotka                259
# ..                           ...                ...
# 194                TomášMartínek               7013
# 109                   MarekNovák               7027
# 184            StanislavBerkovec               7036
# 180                 RomanKubíček               7073
# 171                RadekRozvoral               7099
#
# [214 rows x 2 columns]

# %%
#diagram od deputies attendance total from 2017- 2020 October is divided into 4 pieces in order to make more visible, but I think it didn't help, at least we can see the shape which shows quite varia
deps_attendance_1.plot(kind="barh", fontsize=10)
deps_attendance_2.plot(kind="barh", fontsize=10)
deps_attendance_3.plot(kind="barh", fontsize=10)
deps_attendance_4.plot(kind="barh", fontsize=10)
# Out:
# <AxesSubplot:>

# %%
#another diagram to show all numbers of attendance of deputies(x_axis): 
with sns.axes_style('white'):
    g = sns.catplot(x = "deputy_attendance", data=sorted_deps_attendance_total.iloc[:100], aspect=3,
                       kind="count", color='steelblue')
    g.set_xticklabels(step=3)
     
with sns.axes_style('white'):
    g = sns.catplot(x="deputy_attendance", data=sorted_deps_attendance_total.iloc[100:214], aspect=3,
                       kind="count", color='steelblue')
    g.set_xticklabels(step=3)

# %%
#In column "deputy_attendance_share" calculated share (in %) of deputy attendance in all events from 2017-2020 October
deputies_attendance_total["deputy_attendance_share"] = (deputies_attendance_total["deputy_attendance"] / total_voteEvents)*100
deputies_attendance_total
# Out:
#                          deputies  deputy_attendance  deputy_attendance_share
# 0                      AdamKalous               6290                90.464548
# 1                     AdamVojtěch               5387                77.477348
# 2                 AlenaGajdůšková               5627                80.929095
# 3                  AlexanderČerný               5536                79.620308
# 4                    AlešJuchelka               6728                96.763987
# ..                            ...                ...                      ...
# 209                ZbyněkStanjura               5947                85.531425
# 210                ZdeněkOndráček               5840                83.992521
# 211                   ZdeněkPodal               5423                77.995110
# 212   ZuzanaMajerová Zahradníková               4835                69.538329
# 213                 ZuzanaOžanová               5653                81.303035
#
# [214 rows x 3 columns]

# %%
#histogramma shows deps attendance (in %)
deputies_attendance_graph = deputies_attendance_total.drop('deputy_attendance', axis=1)
my_plot = deputies_attendance_graph.plot(kind='hist',legend=None,title="deputies_attendance_in%")
my_plot.set_xlabel("deputies")
my_plot.set_ylabel("deputy_attendance_share")
# Out:
# Text(0, 0.5, 'deputy_attendance_share')

# %% [markdown]
# ### Task 2B: Attendance of parliamentary clubs in the votings.
# Calculating the number of attendance of clubs and visualization of result

# %%
#creating 2 new columns, where "clubsVote_resInt" contains results of votes of each club, and "clubs_vote" = number of vote  on each versions of votes or absence 
data.loc[: ,('vote_result')] = data.groupby(['meeting_no','vote','vote_no','clubs'])['clubs'].transform('count')
data.loc[: ,('clubsVote_resInt')] = data.groupby(['meeting_no','vote_no', 'clubs'])['vote_result'].transform('max')
votes_clubs = data.groupby(['year', 'meeting_no','vote_no','vote_date', 'clubs', 'vote', 'clubsVote_resInt'])["vote_result"].count().rename("clubs_vote").reset_index()
votes_clubs.head(10)
# Out:
#    year  meeting_no  vote_no        vote_date     clubs         vote  \
# 0  2017           1        2   20. listopadu       ANO           ano
# 1  2017           1        2   20. listopadu       ANO   neprihlasen
# 2  2017           1        2   20. listopadu       ANO        zdrzel
# 3  2017           1        2   20. listopadu   KDU-ČSL           ano
# 4  2017           1        2   20. listopadu   KDU-ČSL        zdrzel
# 5  2017           1        2   20. listopadu      KSČM           ano
# 6  2017           1        2   20. listopadu      KSČM       omluven
# 7  2017           1        2   20. listopadu       ODS           ano
# 8  2017           1        2   20. listopadu    Piráti           ano
# 9  2017           1        2   20. listopadu       SPD           ano
#
#    clubsVote_resInt  clubs_vote
# 0                75          75
# 1                75           1
# 2                75           2
# 3                 9           9
# 4                 9           1
# 5                14          14
# 6                14           1
# 7                25          25
# 8                22          22
# 9                22          22

# %%
#in a new column "clubs_decision" in a new dataFrame "votes_clubs" setting up the final decision of club or their absence
votes_clubs = pd.DataFrame(votes_clubs, columns=['year', 'meeting_no','vote_no','vote_date', 'clubs','vote','clubsVote_resInt','clubs_vote'])
votes_clubs['clubs_decision'] = np.where((votes_clubs['clubsVote_resInt'] == votes_clubs['clubs_vote']), votes_clubs['vote'], '0')
votes_clubs
# Out:
#         year  meeting_no  vote_no        vote_date     clubs         vote  \
# 0       2017           1        2   20. listopadu       ANO           ano
# 1       2017           1        2   20. listopadu       ANO   neprihlasen
# 2       2017           1        2   20. listopadu       ANO        zdrzel
# 3       2017           1        2   20. listopadu   KDU-ČSL           ano
# 4       2017           1        2   20. listopadu   KDU-ČSL        zdrzel
# ...      ...         ...      ...              ...       ...          ...
# 179312  2020          62      235       30. října     TOP09           ano
# 179313  2020          62      235       30. října     TOP09       omluven
# 179314  2020          62      235       30. října      ČSSD           ano
# 179315  2020          62      235       30. října      ČSSD       omluven
# 179316  2020          62      235       30. října      ČSSD        zdrzel
#
#         clubsVote_resInt  clubs_vote clubs_decision
# 0                     75          75            ano
# 1                     75           1              0
# 2                     75           2              0
# 3                      9           9            ano
# 4                      9           1              0
# ...                  ...         ...            ...
# 179312                 4           3              0
# 179313                 4           4        omluven
# 179314                 8           1              0
# 179315                 8           8        omluven
# 179316                 8           5              0
#
# [179317 rows x 9 columns]

# %%
#by applying function "attendance"  in a new column "attendance_clubs" displayed as '1' if decision was 'ano' , "ne", "zdrzel", else Nan 
votes_clubs.loc[:, "attendance_clubs"] = votes_clubs.loc[:, "clubs_decision"].apply(attendance)
votes_clubs
# Out:
#         year  meeting_no  vote_no        vote_date     clubs         vote  \
# 0       2017           1        2   20. listopadu       ANO           ano
# 1       2017           1        2   20. listopadu       ANO   neprihlasen
# 2       2017           1        2   20. listopadu       ANO        zdrzel
# 3       2017           1        2   20. listopadu   KDU-ČSL           ano
# 4       2017           1        2   20. listopadu   KDU-ČSL        zdrzel
# ...      ...         ...      ...              ...       ...          ...
# 179312  2020          62      235       30. října     TOP09           ano
# 179313  2020          62      235       30. října     TOP09       omluven
# 179314  2020          62      235       30. října      ČSSD           ano
# 179315  2020          62      235       30. října      ČSSD       omluven
# 179316  2020          62      235       30. října      ČSSD        zdrzel
#
#         clubsVote_resInt  clubs_vote clubs_decision  attendance_clubs
# 0                     75          75            ano               1.0
# 1                     75           1              0               NaN
# 2                     75           2              0               NaN
# 3                      9           9            ano               1.0
# 4                      9           1              0               NaN
# ...                  ...         ...            ...               ...
# 179312                 4           3              0               NaN
# 179313                 4           4        omluven               0.0
# 179314                 8           1              0               NaN
# 179315                 8           8        omluven               0.0
# 179316                 8           5              0               NaN
#
# [179317 rows x 10 columns]

# %%
#clubs_attendance in total is counted by groupping  and summing up column "clubs_attendance" for each club. 
#In a new column "clubs_attendance_share" calculated share (in persentage) of attendance of each club in all vote events from 2017 unrill October 2020
clubs_attendance_total = votes_clubs.groupby(['clubs'])["attendance_clubs"].sum().rename("clubs_attendance").reset_index()
clubs_attendance_total["clubs_attendance_share%"] = (clubs_attendance_total["clubs_attendance"] / total_voteEvents)*100
clubs_attendance_total
# Out:
#       clubs  clubs_attendance  clubs_attendance_share%
# 0      ANO             6105.0                87.803826
# 1  KDU-ČSL             6345.0                91.255573
# 2     KSČM             6145.0                88.379117
# 3  Nezařaz             3712.0                53.387027
# 4      ODS             6186.0                88.968790
# 5   Piráti             6522.0                93.801237
# 6      SPD             6370.0                91.615130
# 7     STAN             6301.0                90.622753
# 8    TOP09             5550.0                79.821660
# 9     ČSSD             5504.0                79.160075

# %%
#bar shows deps attendance share  in all vote events (2017-October 2020)
clubs_attendance_graph1 = clubs_attendance_total.drop('clubs_attendance', axis=1)
clubs_attendance_graph1.set_index("clubs", inplace=True)
clubs_attendance_graph1.plot(kind="bar", fontsize=14)
# Out:
# <AxesSubplot:xlabel='clubs'>

# %%
#bar shows deps attendance in number of vote events (2017-October 2020)
clubs_attendance_graph2 = clubs_attendance_total.drop('clubs_attendance_share%', axis=1)
clubs_attendance_graph2.set_index("clubs", inplace=True)
clubs_attendance_graph2.plot(kind="bar", fontsize=14)
# Out:
# <AxesSubplot:xlabel='clubs'>

# %% [markdown]
# ### Task#3 How often individual parliamentary clubs vote the same and different:

# %%
# Each club decision is goupped and counted  per meeting 
clubs_vote_per_meeting = votes_clubs.groupby(['year', 'meeting_no', 'clubs',  'vote'])["clubs_decision"].count().rename("count_decisions").reset_index()
clubs_vote_per_meeting
# Out:
#       year  meeting_no   clubs         vote  count_decisions
# 0     2017           1    ANO           ano               13
# 1     2017           1    ANO            ne                3
# 2     2017           1    ANO   neprihlasen               10
# 3     2017           1    ANO       omluven                2
# 4     2017           1    ANO        zdrzel               12
# ...    ...         ...     ...          ...              ...
# 2571  2020          62  TOP09        zdrzel               69
# 2572  2020          62   ČSSD           ano              156
# 2573  2020          62   ČSSD            ne               50
# 2574  2020          62   ČSSD       omluven              232
# 2575  2020          62   ČSSD        zdrzel              148
#
# [2576 rows x 5 columns]

# %%
#from previous table I took only votes "ano", "ne", "zdrzel"  and created a new table with this data
clubs_vote_per_meeting["clubs_decision_res"] = np.where((clubs_vote_per_meeting["vote"] == "neprihlasen") | (clubs_vote_per_meeting["vote"] == "omluven"), np.nan ,clubs_vote_per_meeting['count_decisions'])
clubs_vote_per_meeting.dropna(inplace=True)
clubs_vote_res = clubs_vote_per_meeting[["meeting_no" ,'clubs', 'vote', 'clubs_decision_res' ]]
clubs_vote_res
# Out:
#       meeting_no     clubs    vote  clubs_decision_res
# 0              1      ANO      ano                13.0
# 1              1      ANO       ne                 3.0
# 4              1      ANO   zdrzel                12.0
# 5              1  KDU-ČSL      ano                14.0
# 6              1  KDU-ČSL       ne                 2.0
# ...          ...       ...     ...                 ...
# 2568          62    TOP09       ne                15.0
# 2571          62    TOP09   zdrzel                69.0
# 2572          62     ČSSD      ano               156.0
# 2573          62     ČSSD       ne                50.0
# 2575          62     ČSSD   zdrzel               148.0
#
# [1544 rows x 4 columns]

# %%
#To show diversity of votes among all clubs I used dataset "diamonds" from seaborn. 
clubs_votes = sns.load_dataset('diamonds')
ax = sns.barplot(x="clubs", y="clubs_decision_res", hue='vote', data=clubs_vote_res)
ax.legend(loc='upper right',ncol=4)

# %% [markdown]
# ### Task#4 Are deputies in the same parliamentary club voting the same? Who are the biggest rebels?
# For this task: 1. Created a new dataFrame to solve this task.
# 2.A new column "decision_ofClubs" to assign in words  the result of club's vote
# 3.A new column "same/diff" assign the result of compariance of deputy vote and his/her club as "same" and "different"

# %%
#1-3
df =  pd.DataFrame(data, columns=['meeting_no','vote_no','vote_date','year','vote_time','agenda','clubs','deputies','vote','attendance_deputies','vote_result','clubsVote_resInt'])
df['decision_ofClubs'] = np.where((df['clubsVote_resInt'] == df['vote_result']), df['vote'], '0')
df['decision_ofClubs'] = np.where((df['clubsVote_resInt'] == df['vote_result']), df['vote'], '0')
df['same/diff'] = np.where((df['decision_ofClubs'] == df['vote']), 'same', 'diff')

# %%
#4.Counted all 'same' and 'diff' results of votes on each vote's version  related to each deputy in a new column"same/diff_sum". 
#Assigned Nan values to all rows "neprihlasen and "omluven", then dropped it. 
#Groupped  values of column "same/diff_sum" on each deputy, without vote's version
df_result = df.groupby(["deputies",'vote', 'same/diff'])["same/diff"].count().rename("same/diff_sum").reset_index()
df_result["same/diff_sum"] = np.where((df_result['vote'] == 'neprihlasen') |(df_result['vote'] == 'omluven'), np.nan, df_result['same/diff_sum'])
df_result.dropna(inplace=True)
df_result.head(30)
# Out:
#             deputies    vote same/diff  same/diff_sum
# 0         AdamKalous     ano      diff          275.0
# 1         AdamKalous     ano      same         2600.0
# 2         AdamKalous      ne      diff          290.0
# 3         AdamKalous      ne      same         1746.0
# 8         AdamKalous  zdrzel      diff          685.0
# 9         AdamKalous  zdrzel      same          694.0
# 10       AdamVojtěch     ano      diff          102.0
# 11       AdamVojtěch     ano      same         2175.0
# 12       AdamVojtěch      ne      diff          101.0
# 13       AdamVojtěch      ne      same         1710.0
# 18       AdamVojtěch  zdrzel      diff          650.0
# 19       AdamVojtěch  zdrzel      same          649.0
# 20   AlenaGajdůšková     ano      diff          568.0
# 21   AlenaGajdůšková     ano      same         2108.0
# 22   AlenaGajdůšková      ne      diff          241.0
# 23   AlenaGajdůšková      ne      same         1183.0
# 28   AlenaGajdůšková  zdrzel      diff          761.0
# 29   AlenaGajdůšková  zdrzel      same          766.0
# 30    AlexanderČerný     ano      diff           87.0
# 31    AlexanderČerný     ano      same         2548.0
# 32    AlexanderČerný      ne      diff           56.0
# 33    AlexanderČerný      ne      same         1310.0
# 38    AlexanderČerný  zdrzel      diff          389.0
# 39    AlexanderČerný  zdrzel      same         1146.0
# 40      AlešJuchelka     ano      diff          361.0
# 41      AlešJuchelka     ano      same         2882.0
# 42      AlešJuchelka      ne      diff          171.0
# 43      AlešJuchelka      ne      same         1819.0
# 48      AlešJuchelka  zdrzel      diff          709.0
# 49      AlešJuchelka  zdrzel      same          786.0

# %%
#In order to drop rows "same" and   to sort diff's I created column "rebels", where copied values of diff, and the "same" values  set to Nan value and then dropped it.
#In the end summed up 'diff's'  votes on each deputy, then sorted
df_result["rebels"] = np.where((df_result["same/diff"] == "diff"), df_result["same/diff_sum"], np.nan)
df_result.dropna(inplace=True)
df_result.head(10)
rebels = df_result.groupby(["deputies"])["rebels"].sum().rename("sum_opposite_votes").reset_index()
sorted_rebels = rebels.sort_values(by=("sum_opposite_votes"), ascending=False)
sorted_rebels
# Out:
#               deputies  sum_opposite_votes
# 72          JiříDolejš              2418.0
# 143       OndřejVeselý              2215.0
# 144       PatrikNacher              1835.0
# 43          JanChvojka              1806.0
# 197       VojtěchFilip              1639.0
# ..                 ...                 ...
# 63      JaroslavDvořák               109.0
# 10     BohuslavSobotka               100.0
# 119   MartinStropnický                62.0
# 177      RobertPelikán                39.0
# 73         JiříHlavatý                 1.0
#
# [212 rows x 2 columns]

# %%
#bar shows the most 20 rebels in voting
sorted_rebels_graph = sorted_rebels.set_index("deputies")
my_plot = sorted_rebels_graph[:20].plot(kind='bar')

# %% [markdown]
# ### Bonus tasks:

# %% [markdown]
# ### 1 Visualise some time development in the data (e.g. attendance, change of agreement in voting among individual parliamentary clubs, etc.)
#
# #### Attendance of deputies and clubs during 2017 - 2020 October separately for each year

# %%
#calculating the numbers of all vote events for each year separately
df_total_voteEvents_perYear = pd.DataFrame(total_voteEvents_perYear).reset_index()
df_total_voteEvents_perYear
# Out:
#    year  vote_number_total
# 0  2017                232
# 1  2018               1602
# 2  2019               2943
# 3  2020               2176

# %%
#for each year calculating shares of deputies attendance separately, and in the end concatanated all 4 dataframes
deputies_attendance_year = data.groupby(['year','deputies'])["attendance_deputies"].sum().rename("deputy_attendance").reset_index()
deputies_attendance_2017 = deputies_attendance_year[:203]
deputies_attendance_2017.loc[:, ("total_voteEvents")] = 232
deputies_attendance_2017.loc[:, ("share_ofAttendance")] = ((deputies_attendance_2017.loc[:,("deputy_attendance")]) / (deputies_attendance_2017.loc[:, ("total_voteEvents")]))*100
deputies_attendance_2018 = deputies_attendance_year[203:407]
deputies_attendance_2018.loc[:,("total_voteEvents")] = 1602
deputies_attendance_2018.loc[:,("share_ofAttendance")] = ((deputies_attendance_2018.loc[:, ("deputy_attendance")]) / (deputies_attendance_2018.loc[:, ("total_voteEvents")]))*100
deputies_attendance_2019 = deputies_attendance_year[407:612]
deputies_attendance_2019.loc[:,("total_voteEvents")] = 2943
deputies_attendance_2019.loc[:, ("share_ofAttendance")] = ((deputies_attendance_2019.loc[:, ("deputy_attendance")]) / (deputies_attendance_2019.loc[:,("total_voteEvents")]))*100
deputies_attendance_2020 = deputies_attendance_year.loc[612:]
deputies_attendance_2020.loc[:, ("total_voteEvents")] = 2176
deputies_attendance_2020.loc[:, ("share_ofAttendance")] = ((deputies_attendance_2020.loc[:, ("deputy_attendance")] / (deputies_attendance_2020.loc[:, ("total_voteEvents")]))*100)
frames = [deputies_attendance_2017, deputies_attendance_2018, deputies_attendance_2019, deputies_attendance_2020]
result = pd.concat(frames)
result
# Out:
#      year                      deputies  deputy_attendance  total_voteEvents  \
# 0    2017                    AdamKalous                232               232
# 1    2017                   AdamVojtěch                226               232
# 2    2017               AlenaGajdůšková                230               232
# 3    2017                AlexanderČerný                225               232
# 4    2017                  AlešJuchelka                230               232
# ..    ...                           ...                ...               ...
# 809  2020                ZbyněkStanjura               1629              2176
# 810  2020                ZdeněkOndráček               1625              2176
# 811  2020                   ZdeněkPodal               1130              2176
# 812  2020   ZuzanaMajerová Zahradníková                913              2176
# 813  2020                 ZuzanaOžanová               1463              2176
#
#      share_ofAttendance
# 0            100.000000
# 1             97.413793
# 2             99.137931
# 3             96.982759
# 4             99.137931
# ..                  ...
# 809           74.862132
# 810           74.678309
# 811           51.930147
# 812           41.957721
# 813           67.233456
#
# [814 rows x 5 columns]

# %%
plt.figure(figsize=(9,12)) 

plt.subplot(321) 
deputies_attendance_2017['share_ofAttendance'].plot.hist(color='Green')
plt.subplot(322)
deputies_attendance_2018['share_ofAttendance'].plot.hist(color='Blue')
plt.subplot(323)
deputies_attendance_2019['share_ofAttendance'].plot.hist(color='Orange')
plt.subplot(324)
deputies_attendance_2020['share_ofAttendance'].plot.hist(color='Purple')

plt.show()

# %%
#bar shows deps attendance and number of all vote events (2017). For  readability I showed just data of  30 deputies for 2017
deputies_attendance_2017_graph1 = deputies_attendance_2017.drop('share_ofAttendance', axis=1)
deputies_attendance_2017_graph1.set_index("deputies", inplace=True)
deputies_attendance_2017_graph1[:30].plot(kind="bar", fontsize=12)
# Out:
# <AxesSubplot:xlabel='deputies'>

# %%
#total = data.groupby(['year', 'meeting_no', 'vote_date'])["vote_no"].nunique().rename("vote_number_total").reset_index()
#total_voteEvents_perMeeting = total.groupby(['year', 'meeting_no'])["vote_number_total"].sum()
total_voteEvents_perYear = total.groupby(['year'])["vote_number_total"].sum()
#total_voteEvents_perYear
#total_voteEvents = total["vote_number_total"].sum()
total_voteEvents
total_voteEvents_perYear
# Out:
# year
# 2017     232
# 2018    1602
# 2019    2943
# 2020    2176
# Name: vote_number_total, dtype: int64

# %%
clubs_attendance_Year = votes_clubs.groupby(['year', 'clubs'])["attendance_clubs"].sum().rename("clubs_attendance").reset_index()
clubs_attendance_2017 = clubs_attendance_Year[0:9]
clubs_attendance_2017.loc[:,("all_voteEvents")] = 232
clubs_attendance_2017.loc[:, ("share_ofAttendance")] = ((clubs_attendance_2017.loc[:, ("clubs_attendance")]) / (clubs_attendance_2017.loc[:, ("all_voteEvents")]) * 100)
clubs_attendance_2018 = clubs_attendance_Year[9:18]
clubs_attendance_2018.loc[:,("all_voteEvents")] = 1602
clubs_attendance_2018.loc[:, ("share_ofAttendance")] = ((clubs_attendance_2018.loc[:, ("clubs_attendance")]) / (clubs_attendance_2018.loc[:, ("all_voteEvents")]) * 100)

clubs_attendance_2019 = clubs_attendance_Year[18:28]
clubs_attendance_2019.loc[:,("all_voteEvents")] = 2943
clubs_attendance_2019.loc[:, ("share_ofAttendance")] = ((clubs_attendance_2019.loc[:, ("clubs_attendance")]) / (clubs_attendance_2019.loc[:, ("all_voteEvents")]) * 100)

clubs_attendance_2020 = clubs_attendance_Year[28:]
clubs_attendance_2020.loc[:,("all_voteEvents")] = 2176
clubs_attendance_2020.loc[:, ("share_ofAttendance")] = ((clubs_attendance_2020.loc[:, ("clubs_attendance")]) / (clubs_attendance_2020.loc[:, ("all_voteEvents")]) * 100)

clubs_attendance_2020
# Out:
#     year     clubs  clubs_attendance  all_voteEvents  share_ofAttendance
# 28  2020      ANO             1363.0            2176           62.637868
# 29  2020  KDU-ČSL             1794.0            2176           82.444853
# 30  2020     KSČM             1404.0            2176           64.522059
# 31  2020  Nezařaz             1403.0            2176           64.476103
# 32  2020      ODS             1526.0            2176           70.128676
# 33  2020   Piráti             1757.0            2176           80.744485
# 34  2020      SPD             1658.0            2176           76.194853
# 35  2020     STAN             1591.0            2176           73.115809
# 36  2020    TOP09             1034.0            2176           47.518382
# 37  2020     ČSSD             1189.0            2176           54.641544

# %%
clubs_attendance_2017_graph = clubs_attendance_2017.drop('share_ofAttendance', axis=1)
clubs_attendance_2017_graph.plot(kind="bar", fontsize=10)
# Out:
# <AxesSubplot:>

# %%
clubs_attendance_2018_graph = clubs_attendance_2018.drop('share_ofAttendance', axis=1)
clubs_attendance_2018_graph.plot(kind="bar", fontsize=10)
# Out:
# <AxesSubplot:>

# %%
clubs_attendance_2019_graph = clubs_attendance_2019.drop('share_ofAttendance', axis=1)
clubs_attendance_2019_graph.plot(kind="bar", fontsize=10)
# Out:
# <AxesSubplot:>

# %%
clubs_attendance_2020_graph = clubs_attendance_2020.drop('share_ofAttendance', axis=1)
clubs_attendance_2020_graph.plot(kind="bar", fontsize=10)
# Out:
# <AxesSubplot:>

# %%
frames2 = [clubs_attendance_2017, clubs_attendance_2018, clubs_attendance_2019, clubs_attendance_2020]
result2 = pd.concat(frames2)
result2
# Out:
#     year     clubs  clubs_attendance  all_voteEvents  share_ofAttendance
# 0   2017      ANO              232.0             232          100.000000
# 1   2017  KDU-ČSL              231.0             232           99.568966
# 2   2017     KSČM              228.0             232           98.275862
# 3   2017      ODS              229.0             232           98.706897
# 4   2017   Piráti              232.0             232          100.000000
# 5   2017      SPD              232.0             232          100.000000
# 6   2017     STAN              238.0             232          102.586207
# 7   2017    TOP09              223.0             232           96.120690
# 8   2017     ČSSD              220.0             232           94.827586
# 9   2018      ANO             1590.0            1602           99.250936
# 10  2018  KDU-ČSL             1518.0            1602           94.756554
# 11  2018     KSČM             1578.0            1602           98.501873
# 12  2018      ODS             1561.0            1602           97.440699
# 13  2018   Piráti             1605.0            1602          100.187266
# 14  2018      SPD             1592.0            1602           99.375780
# 15  2018     STAN             1592.0            1602           99.375780
# 16  2018    TOP09             1493.0            1602           93.196005
# 17  2018     ČSSD             1359.0            1602           84.831461
# 18  2019      ANO             2920.0            2943           99.218485
# 19  2019  KDU-ČSL             2802.0            2943           95.208970
# 20  2019     KSČM             2935.0            2943           99.728169
# 21  2019  Nezařaz             2309.0            2943           78.457356
# 22  2019      ODS             2870.0            2943           97.519538
# 23  2019   Piráti             2928.0            2943           99.490316
# 24  2019      SPD             2888.0            2943           98.131159
# 25  2019     STAN             2880.0            2943           97.859327
# 26  2019    TOP09             2800.0            2943           95.141013
# 27  2019     ČSSD             2736.0            2943           92.966361
# 28  2020      ANO             1363.0            2176           62.637868
# 29  2020  KDU-ČSL             1794.0            2176           82.444853
# 30  2020     KSČM             1404.0            2176           64.522059
# 31  2020  Nezařaz             1403.0            2176           64.476103
# 32  2020      ODS             1526.0            2176           70.128676
# 33  2020   Piráti             1757.0            2176           80.744485
# 34  2020      SPD             1658.0            2176           76.194853
# 35  2020     STAN             1591.0            2176           73.115809
# 36  2020    TOP09             1034.0            2176           47.518382
# 37  2020     ČSSD             1189.0            2176           54.641544

# %%
#below 2 bars show the changes in clubs attendance during 2017 - 2020 October
result2_gr = result2.set_index("clubs")
result2_gr.plot(kind="bar", fontsize=10)
# Out:
# <AxesSubplot:xlabel='clubs'>

# %%
clubs_attendance = sns.load_dataset('diamonds')
ax = sns.barplot(x="clubs", y = "share_ofAttendance", hue='year', data=result2)
ax.legend(loc='upper right',ncol=4)

# %% [markdown]
# #### Find individual deputies who have the most similar attendance:
# not solved. I just took data  attendance of deputies per meeting (62 meetings), removed Nan and 0 values, sorted and displayed the max values around 1000. But I didn't take data on each vote to get exact matches of attendance deputies.
# Very interesting to see your solution of this task.

# %%
deputies_attendance_meeting = data.groupby(['year','meeting_no', 'deputies'])["attendance_deputies"].sum().rename("deputy_attendance").reset_index()
deps_meeting_duplicates = deputies_attendance_meeting[deputies_attendance_meeting.duplicated([('deputy_attendance')], keep=False)]
deps_meeting_duplicates[('deputy_attendance')] = np.where((deps_meeting_duplicates[("deputy_attendance")] == 0 ), np.nan, deps_meeting_duplicates[('deputy_attendance')])
deps_meeting_duplicates.dropna(inplace=True)
sorted_deps_attendance_meeting = deps_meeting_duplicates.sort_values(by=("deputy_attendance"), ascending=False)
sorted_deps_attendance_meeting.head(80)
# Out:
# <ipython-input-224-9bfbb5813e1c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deps_meeting_duplicates[('deputy_attendance')] = np.where((deps_meeting_duplicates[("deputy_attendance")] == 0 ), np.nan, deps_meeting_duplicates[('deputy_attendance')])
# <ipython-input-224-9bfbb5813e1c>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deps_meeting_duplicates.dropna(inplace=True)
#       year  meeting_no           deputies  deputy_attendance
# 5362  2019          30      RadekRozvoral             1071.0
# 5282  2019          30        KamalFarhan             1071.0
# 5325  2019          30    MiloslavaRutová             1071.0
# 5370  2019          30       RomanKubíček             1071.0
# 5224  2019          30   FrantišekPetrtýl             1071.0
# ...    ...         ...                ...                ...
# 5317  2019          30   MikulášFerjenčík             1054.0
# 5388  2019          30       VojtěchFilip             1044.0
# 5213  2019          30      DanaBalcarová             1044.0
# 5372  2019          30       RomanSklenák             1043.0
# 5267  2019          30    JaroslavMartinů             1043.0
#
# [80 rows x 4 columns]

# %%
deputies_attendance_vote = data.groupby(['year','meeting_no', 'vote_no','deputies'])["attendance_deputies"].sum().rename("deputy_attendance").reset_index()
deps_vote_duplicates = deputies_attendance_vote[deputies_attendance_vote.duplicated(['deputies'], keep=False)]
deps_vote_duplicates.loc[:,('deputy_attendance')] = np.where((deps_vote_duplicates.loc[: ,("deputy_attendance")] == 0 ), np.nan, deps_vote_duplicates.loc[:, ('deputy_attendance')])
deps_vote_duplicates.sort_values(by=("deputy_attendance"))
deps_vote_duplicates.dropna(inplace=True)
deps_vote_duplicates
# Out:
#          year  meeting_no  vote_no                      deputies  \
# 0        2017           1        2                    AdamKalous
# 1        2017           1        2                   AdamVojtěch
# 2        2017           1        2               AlenaGajdůšková
# 3        2017           1        2                AlexanderČerný
# 4        2017           1        2                  AlešJuchelka
# ...       ...         ...      ...                           ...
# 1388998  2020          62      235                  VítKaňkovský
# 1388999  2020          62      235                    VítRakušan
# 1389001  2020          62      235                  VěraKovářová
# 1389006  2020          62      235   ZuzanaMajerová Zahradníková
# 1389007  2020          62      235                 ZuzanaOžanová
#
#          deputy_attendance
# 0                      1.0
# 1                      1.0
# 2                      1.0
# 3                      1.0
# 4                      1.0
# ...                    ...
# 1388998                1.0
# 1388999                1.0
# 1389001                1.0
# 1389006                1.0
# 1389007                1.0
#
# [1089079 rows x 5 columns]
